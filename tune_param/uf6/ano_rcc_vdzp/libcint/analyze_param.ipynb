# %%
import os.path
import math
# %matplotlib inline
# %matplotlib qt

# %%
prefix = 'uf6_ano_rcc_vdzp_libcint_'
taus = ['1e-8', '1e-6', '1e-4']                                                                                                    
sigmas = ['1e-1','5e-2','1e-2','5e-3','1e-3','5e-4']                            
maxquals = [1000, 500, 2000, 200, 5000, 100, 50, 20, 1, 20000] 
maxquals_sorted = sorted(maxquals)
maxquals_small = [1000, 500, 200, 100, 50, 20, 1] 
root = '/Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/'

# %%
 # %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager
from matplotlib.ticker import NullLocator
matplotlib.rcParams['pdf.fonttype'] = 42
rgb_colors = [(  0, 78,139), # Dark blue
              (  0,130,183), # Blue
              ( 97,202,228), # Light blue
              (255,205, 65), # Dark yellow
              (225, 27, 46), # Reddish
              (  0,  0,  0), # Black
             ]

colors = []
for c in rgb_colors:
    colors.append(tuple([float(p) / 255.0 for p in c]))
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = 7
plt.rcParams["figure.figsize"] = [3.25, 3.5]
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using qt instead.

# %%
def latexScientific(x):
    s = '%.2e' % (x,)
    s = '$' + s.replace('e+0',r'\times 10^{') + '}$'
    return s

# %%
def parseOut(fname):
    sfTimes = {}
    if not os.path.exists(fname):
        return None
    f = open(fname)
    for line in f:
        # TIMING IN FIRST STEP
        if 'Cholesky-RI-Pivots-ERI count' in line:
            sfTimes['NERI1'] = int(line.split('= ')[-1])
            
        if 'Cholesky-RI-Pivots-ERI duration' in line:
            sfTimes['ERI1'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-ERIvec duration     =' in line:
            sfTimes['ERIvec'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-ERIcopy duration    =' in line:
            sfTimes['ERIcopy'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-ERItrans duration   =' in line:
            sfTimes['ERItrans'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-CDalgMM duration    =' in line:
            sfTimes['CDalgMM'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-CDalgMV duration    =' in line:
            sfTimes['CDalgMV'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-Shrink count        =' in line:
            sfTimes['Shrink count'] = int(line.split('= ')[-1])
            
        if 'Cholesky-RI-Shrink duration     =' in line:
            sfTimes['Shrink'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-misc duration       =' in line:
            sfTimes['misc'] = float(line.split('= ')[-1].split()[0])
            
            
        if 'Cholesky-RI-Dynamic-ERI-Pivots duration =' in line:
            sfTimes['T1'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI auxiliary dimension =' in line:
            sfTimes['Aux dim'] = int(line.split('= ')[-1])
        
        
        
        # TIMING IN SECOND STEP
        if 'Cholesky-RI-PivotRI-ERI count       = ' in line:
            sfTimes['NERI2'] = int(line.split('= ')[-1])
            
        if 'Cholesky-RI-PivotRI-ERI duration    =' in line:
            sfTimes['ERI2'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-PivotRI-3index duration =' in line:
            sfTimes['PivotRI-3index'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-PivotRI-2index duration =' in line:
            sfTimes['PivotRI-2index'] = float(line.split('= ')[-1].split()[0])
            
        if 'RI-ERI3-Transformation-Cholesky duration =' in line:
            sfTimes['Trans-Cholesky'] = float(line.split('= ')[-1].split()[0])
            
        if 'RI-ERI3-Transformation-TriInv duration   =' in line:
            sfTimes['Trans-TriInv'] = float(line.split('= ')[-1].split()[0])
            
        if 'RI-ERI3-Transformation-Gemm duration     =' in line:
            sfTimes['Trans-Gemm'] = float(line.split('= ')[-1].split()[0])
            
        if 'RI-ERI3-Transformation-Copy duration     =' in line:
            sfTimes['Trans-Copy'] = float(line.split('= ')[-1].split()[0])
            
        if 'RI-ERI3-Transformation duration =' in line:
            sfTimes['Trans'] = float(line.split('= ')[-1].split()[0])
            
        if 'Cholesky-RI-PivotRI duration =' in line:
            sfTimes['T2'] = float(line.split('= ')[-1].split()[0])
            
            
        if 'Cholesky-RI duration =' in line:
            sfTimes['TotalT'] = float(line.split('= ')[-1].split()[0])
    f.close()
    return sfTimes

# %%
times = {}


for tau in taus:
    for sigma in sigmas:
        for maxqual in maxquals:

            fname = root + prefix

            fname += 't%s_s%s_m%d' % (tau,sigma,maxqual)

            fname += '.out'

            print(fname)

            times[(tau,sigma,maxqual)] = parseOut(fname)
# Out:
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-1_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-2_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-2_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-3_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s1e-3_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-8_s5e-4_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-1_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-2_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-2_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-3_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s1e-3_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-6_s5e-4_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-1_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-2_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-2_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-3_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s1e-3_m20000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m1000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m500.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m2000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m200.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m5000.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m100.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m50.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m20.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m1.out
# /Users/aodongliu/LiGroup/CD/tune_param/uf6/ano_rcc_vdzp/libcint/uf6_ano_rcc_vdzp_libcint_t1e-4_s5e-4_m20000.out

# %%
times
# Out:
# {('1e-8', '1e-1', 1000): {'NERI1': 31991,
#   'ERI1': 324.25,
#   'ERIvec': 20.483,
#   'ERIcopy': 0.095025,
#   'ERItrans': 0.1021,
#   'CDalgMM': 0.16691,
#   'CDalgMV': 0.089028,
#   'Shrink count': 13,
#   'Shrink': 0.80407,
#   'misc': 2.7176,
#   'T1': 24.458,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 302.33,
#   'PivotRI-3index': 15.483,
#   'PivotRI-2index': 0.001971,
#   'Trans-Cholesky': 0.010133,
#   'Trans-TriInv': 0.013408,
#   'Trans-Gemm': 0.1576,
#   'Trans-Copy': 0.092873,
#   'Trans': 0.2742,
#   'T2': 15.759,
#   'TotalT': 40.218},
#  ('1e-8', '1e-1', 500): {'NERI1': 29850,
#   'ERI1': 330.1,
#   'ERIvec': 21.664,
#   'ERIcopy': 0.032307,
#   'ERItrans': 0.028296,
#   'CDalgMM': 0.14651,
#   'CDalgMV': 0.081256,
#   'Shrink count': 18,
#   'Shrink': 0.96887,
#   'misc': 2.7152,
#   'T1': 25.637,
#   'Aux dim': 1972,
#   'NERI2': 31556,
#   'ERI2': 301.71,
#   'PivotRI-3index': 15.788,
#   'PivotRI-2index': 0.0031756,
#   'Trans-Cholesky': 0.010247,
#   'Trans-TriInv': 0.012865,
#   'Trans-Gemm': 0.16208,
#   'Trans-Copy': 0.085292,
#   'Trans': 0.27065,
#   'T2': 16.062,
#   'TotalT': 41.7},
#  ('1e-8', '1e-1', 2000): {'NERI1': 33871,
#   'ERI1': 324.93,
#   'ERIvec': 22.602,
#   'ERIcopy': 0.059665,
#   'ERItrans': 0.030873,
#   'CDalgMM': 0.34393,
#   'CDalgMV': 0.15722,
#   'Shrink count': 10,
#   'Shrink': 0.74351,
#   'misc': 3.6808,
#   'T1': 27.618,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 302.04,
#   'PivotRI-3index': 15.696,
#   'PivotRI-2index': 0.0025424,
#   'Trans-Cholesky': 0.012215,
#   'Trans-TriInv': 0.012819,
#   'Trans-Gemm': 0.16866,
#   'Trans-Copy': 0.10347,
#   'Trans': 0.29732,
#   'T2': 15.996,
#   'TotalT': 43.615},
#  ('1e-8', '1e-1', 200): {'NERI1': 28773,
#   'ERI1': 325.49,
#   'ERIvec': 21.268,
#   'ERIcopy': 0.025391,
#   'ERItrans': 0.028884,
#   'CDalgMM': 0.17196,
#   'CDalgMV': 0.108,
#   'Shrink count': 31,
#   'Shrink': 1.6035,
#   'misc': 2.9045,
#   'T1': 26.11,
#   'Aux dim': 1972,
#   'NERI2': 31671,
#   'ERI2': 302.01,
#   'PivotRI-3index': 15.518,
#   'PivotRI-2index': 0.0033244,
#   'Trans-Cholesky': 0.0094042,
#   'Trans-TriInv': 0.012946,
#   'Trans-Gemm': 0.15334,
#   'Trans-Copy': 0.10453,
#   'Trans': 0.28044,
#   'T2': 15.802,
#   'TotalT': 41.914},
#  ('1e-8', '1e-1', 5000): {'NERI1': 34010,
#   'ERI1': 324.57,
#   'ERIvec': 22.699,
#   'ERIcopy': 0.057012,
#   'ERItrans': 0.032135,
#   'CDalgMM': 0.20406,
#   'CDalgMV': 0.10896,
#   'Shrink count': 9,
#   'Shrink': 0.71631,
#   'misc': 2.7449,
#   'T1': 26.563,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 301.91,
#   'PivotRI-3index': 15.502,
#   'PivotRI-2index': 0.0018614,
#   'Trans-Cholesky': 0.0096627,
#   'Trans-TriInv': 0.013432,
#   'Trans-Gemm': 0.14786,
#   'Trans-Copy': 0.10498,
#   'Trans': 0.27609,
#   'T2': 15.78,
#   'TotalT': 42.346},
#  ('1e-8', '1e-1', 100): {'NERI1': 27780,
#   'ERI1': 317.62,
#   'ERIvec': 19.42,
#   'ERIcopy': 0.014543,
#   'ERItrans': 0.038467,
#   'CDalgMM': 0.13548,
#   'CDalgMV': 0.074015,
#   'Shrink count': 49,
#   'Shrink': 2.213,
#   'misc': 2.7097,
#   'T1': 24.605,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 301.54,
#   'PivotRI-3index': 15.718,
#   'PivotRI-2index': 0.0034015,
#   'Trans-Cholesky': 0.0093868,
#   'Trans-TriInv': 0.012827,
#   'Trans-Gemm': 0.15992,
#   'Trans-Copy': 0.097365,
#   'Trans': 0.27966,
#   'T2': 16.001,
#   'TotalT': 40.609},
#  ('1e-8', '1e-1', 50): {'NERI1': 27267,
#   'ERI1': 313.91,
#   'ERIvec': 18.062,
#   'ERIcopy': 0.017634,
#   'ERItrans': 0.036846,
#   'CDalgMM': 0.21989,
#   'CDalgMV': 0.072265,
#   'Shrink count': 81,
#   'Shrink': 3.7242,
#   'misc': 2.7451,
#   'T1': 24.878,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 302.04,
#   'PivotRI-3index': 15.862,
#   'PivotRI-2index': 0.002631,
#   'Trans-Cholesky': 0.0095244,
#   'Trans-TriInv': 0.013542,
#   'Trans-Gemm': 0.15275,
#   'Trans-Copy': 0.095533,
#   'Trans': 0.27151,
#   'T2': 16.136,
#   'TotalT': 41.015},
#  ('1e-8', '1e-1', 20): {'NERI1': 26826,
#   'ERI1': 310.7,
#   'ERIvec': 17.189,
#   'ERIcopy': 0.028578,
#   'ERItrans': 0.03576,
#   'CDalgMM': 0.2746,
#   'CDalgMV': 0.080585,
#   'Shrink count': 169,
#   'Shrink': 7.3067,
#   'misc': 3.2003,
#   'T1': 28.115,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 302.06,
#   'PivotRI-3index': 15.756,
#   'PivotRI-2index': 0.0092711,
#   'Trans-Cholesky': 0.018882,
#   'Trans-TriInv': 0.012499,
#   'Trans-Gemm': 0.15373,
#   'Trans-Copy': 0.1176,
#   'Trans': 0.30294,
#   'T2': 16.069,
#   'TotalT': 44.185},
#  ('1e-8', '1e-1', 1): {'NERI1': 26437,
#   'ERI1': 307.26,
#   'ERIvec': 18.816,
#   'ERIcopy': 0.060623,
#   'ERItrans': 0.048328,
#   'CDalgMM': 2.943,
#   'CDalgMV': 0.074382,
#   'Shrink count': 1970,
#   'Shrink': 81.707,
#   'misc': 3.7362,
#   'T1': 107.39,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 302.13,
#   'PivotRI-3index': 15.63,
#   'PivotRI-2index': 0.0035617,
#   'Trans-Cholesky': 0.015845,
#   'Trans-TriInv': 0.013178,
#   'Trans-Gemm': 0.16918,
#   'Trans-Copy': 0.10226,
#   'Trans': 0.30069,
#   'T2': 15.935,
#   'TotalT': 123.32},
#  ('1e-8', '1e-1', 20000): {'NERI1': 34010,
#   'ERI1': 324.08,
#   'ERIvec': 22.524,
#   'ERIcopy': 0.055872,
#   'ERItrans': 0.030055,
#   'CDalgMM': 0.20086,
#   'CDalgMV': 0.10018,
#   'Shrink count': 9,
#   'Shrink': 0.71858,
#   'misc': 2.7386,
#   'T1': 26.369,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 302.28,
#   'PivotRI-3index': 15.512,
#   'PivotRI-2index': 0.00481,
#   'Trans-Cholesky': 0.013576,
#   'Trans-TriInv': 0.013091,
#   'Trans-Gemm': 0.19936,
#   'Trans-Copy': 0.096904,
#   'Trans': 0.32307,
#   'T2': 15.84,
#   'TotalT': 42.211},
#  ('1e-8', '5e-2', 1000): {'NERI1': 31817,
#   'ERI1': 331.11,
#   'ERIvec': 25.085,
#   'ERIcopy': 0.040187,
#   'ERItrans': 0.026156,
#   'CDalgMM': 0.15085,
#   'CDalgMV': 0.09324,
#   'Shrink count': 12,
#   'Shrink': 0.96191,
#   'misc': 2.7463,
#   'T1': 29.103,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 301.58,
#   'PivotRI-3index': 15.559,
#   'PivotRI-2index': 0.013629,
#   'Trans-Cholesky': 0.008624,
#   'Trans-TriInv': 0.011972,
#   'Trans-Gemm': 0.1494,
#   'Trans-Copy': 0.1065,
#   'Trans': 0.27667,
#   'T2': 15.849,
#   'TotalT': 44.956},
#  ('1e-8', '5e-2', 500): {'NERI1': 29960,
#   'ERI1': 327.92,
#   'ERIvec': 23.763,
#   'ERIcopy': 0.027234,
#   'ERItrans': 0.019327,
#   'CDalgMM': 0.12656,
#   'CDalgMV': 0.088952,
#   'Shrink count': 18,
#   'Shrink': 1.071,
#   'misc': 2.8939,
#   'T1': 27.99,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 301.29,
#   'PivotRI-3index': 15.542,
#   'PivotRI-2index': 0.0079888,
#   'Trans-Cholesky': 0.0093245,
#   'Trans-TriInv': 0.013215,
#   'Trans-Gemm': 0.15619,
#   'Trans-Copy': 0.10189,
#   'Trans': 0.28077,
#   'T2': 15.832,
#   'TotalT': 43.824},
#  ('1e-8', '5e-2', 2000): {'NERI1': 34473,
#   'ERI1': 333.25,
#   'ERIvec': 27.477,
#   'ERIcopy': 0.058497,
#   'ERItrans': 0.023778,
#   'CDalgMM': 0.22072,
#   'CDalgMV': 0.12153,
#   'Shrink count': 9,
#   'Shrink': 0.85899,
#   'misc': 2.8154,
#   'T1': 31.576,
#   'Aux dim': 1972,
#   'NERI2': 31556,
#   'ERI2': 302.53,
#   'PivotRI-3index': 15.53,
#   'PivotRI-2index': 0.0016996,
#   'Trans-Cholesky': 0.011105,
#   'Trans-TriInv': 0.021157,
#   'Trans-Gemm': 0.16627,
#   'Trans-Copy': 0.095266,
#   'Trans': 0.29398,
#   'T2': 15.825,
#   'TotalT': 47.404},
#  ('1e-8', '5e-2', 200): {'NERI1': 28445,
#   'ERI1': 325.13,
#   'ERIvec': 23.079,
#   'ERIcopy': 0.022636,
#   'ERItrans': 0.024486,
#   'CDalgMM': 0.14568,
#   'CDalgMV': 0.083222,
#   'Shrink count': 30,
#   'Shrink': 1.6198,
#   'misc': 2.907,
#   'T1': 27.882,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.82,
#   'PivotRI-3index': 15.53,
#   'PivotRI-2index': 0.0065909,
#   'Trans-Cholesky': 0.01062,
#   'Trans-TriInv': 0.013367,
#   'Trans-Gemm': 0.16589,
#   'Trans-Copy': 0.12373,
#   'Trans': 0.3138,
#   'T2': 15.851,
#   'TotalT': 43.735},
#  ('1e-8', '5e-2', 5000): {'NERI1': 35109,
#   'ERI1': 333.43,
#   'ERIvec': 27.663,
#   'ERIcopy': 0.085738,
#   'ERItrans': 0.027519,
#   'CDalgMM': 0.23002,
#   'CDalgMV': 0.11113,
#   'Shrink count': 7,
#   'Shrink': 0.65683,
#   'misc': 2.924,
#   'T1': 31.698,
#   'Aux dim': 1970,
#   'NERI2': 31323,
#   'ERI2': 301.93,
#   'PivotRI-3index': 15.591,
#   'PivotRI-2index': 0.0036104,
#   'Trans-Cholesky': 0.013103,
#   'Trans-TriInv': 0.012455,
#   'Trans-Gemm': 0.26114,
#   'Trans-Copy': 0.091723,
#   'Trans': 0.37865,
#   'T2': 15.973,
#   'TotalT': 47.674},
#  ('1e-8', '5e-2', 100): {'NERI1': 27837,
#   'ERI1': 317.38,
#   'ERIvec': 19.803,
#   'ERIcopy': 0.048324,
#   'ERItrans': 0.032304,
#   'CDalgMM': 0.14464,
#   'CDalgMV': 0.074294,
#   'Shrink count': 48,
#   'Shrink': 2.3165,
#   'misc': 2.7313,
#   'T1': 25.15,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 302.37,
#   'PivotRI-3index': 15.969,
#   'PivotRI-2index': 0.0029291,
#   'Trans-Cholesky': 0.0098769,
#   'Trans-TriInv': 0.012921,
#   'Trans-Gemm': 0.15522,
#   'Trans-Copy': 0.094962,
#   'Trans': 0.27318,
#   'T2': 16.246,
#   'TotalT': 41.397},
#  ('1e-8', '5e-2', 50): {'NERI1': 27002,
#   'ERI1': 312.54,
#   'ERIvec': 18.541,
#   'ERIcopy': 0.059858,
#   'ERItrans': 0.027469,
#   'CDalgMM': 0.19319,
#   'CDalgMV': 0.098552,
#   'Shrink count': 80,
#   'Shrink': 3.6666,
#   'misc': 3.0692,
#   'T1': 25.656,
#   'Aux dim': 1970,
#   'NERI2': 31323,
#   'ERI2': 301.38,
#   'PivotRI-3index': 15.543,
#   'PivotRI-2index': 0.0021956,
#   'Trans-Cholesky': 0.010137,
#   'Trans-TriInv': 0.012318,
#   'Trans-Gemm': 0.15206,
#   'Trans-Copy': 0.087912,
#   'Trans': 0.26258,
#   'T2': 15.808,
#   'TotalT': 41.465},
#  ('1e-8', '5e-2', 20): {'NERI1': 26778,
#   'ERI1': 310.23,
#   'ERIvec': 18.249,
#   'ERIcopy': 0.029831,
#   'ERItrans': 0.02868,
#   'CDalgMM': 0.26088,
#   'CDalgMV': 0.074056,
#   'Shrink count': 168,
#   'Shrink': 7.2447,
#   'misc': 2.8765,
#   'T1': 28.764,
#   'Aux dim': 1972,
#   'NERI2': 31440,
#   'ERI2': 302.82,
#   'PivotRI-3index': 15.491,
#   'PivotRI-2index': 0.0029203,
#   'Trans-Cholesky': 0.016548,
#   'Trans-TriInv': 0.012653,
#   'Trans-Gemm': 0.14958,
#   'Trans-Copy': 0.097805,
#   'Trans': 0.27678,
#   'T2': 15.771,
#   'TotalT': 44.537},
#  ('1e-8', '5e-2', 1): {'NERI1': 26437,
#   'ERI1': 306.49,
#   'ERIvec': 18.408,
#   'ERIcopy': 0.059148,
#   'ERItrans': 0.038098,
#   'CDalgMM': 2.7759,
#   'CDalgMV': 0.057924,
#   'Shrink count': 1970,
#   'Shrink': 79.772,
#   'misc': 3.3018,
#   'T1': 104.41,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 301.65,
#   'PivotRI-3index': 15.571,
#   'PivotRI-2index': 0.0041498,
#   'Trans-Cholesky': 0.014464,
#   'Trans-TriInv': 0.012816,
#   'Trans-Gemm': 0.14744,
#   'Trans-Copy': 0.10517,
#   'Trans': 0.28011,
#   'T2': 15.855,
#   'TotalT': 120.27},
#  ('1e-8', '5e-2', 20000): {'NERI1': 35109,
#   'ERI1': 333.16,
#   'ERIvec': 27.93,
#   'ERIcopy': 0.092951,
#   'ERItrans': 0.027739,
#   'CDalgMM': 0.25343,
#   'CDalgMV': 0.16156,
#   'Shrink count': 7,
#   'Shrink': 0.67367,
#   'misc': 2.9586,
#   'T1': 32.098,
#   'Aux dim': 1970,
#   'NERI2': 31323,
#   'ERI2': 301.54,
#   'PivotRI-3index': 15.559,
#   'PivotRI-2index': 0.0029738,
#   'Trans-Cholesky': 0.014197,
#   'Trans-TriInv': 0.01255,
#   'Trans-Gemm': 0.24271,
#   'Trans-Copy': 0.091074,
#   'Trans': 0.36068,
#   'T2': 15.923,
#   'TotalT': 48.024},
#  ('1e-8', '1e-2', 1000): {'NERI1': 31887,
#   'ERI1': 336.59,
#   'ERIvec': 30.378,
#   'ERIcopy': 0.039675,
#   'ERItrans': 0.026853,
#   'CDalgMM': 0.15322,
#   'CDalgMV': 0.096102,
#   'Shrink count': 11,
#   'Shrink': 0.82388,
#   'misc': 2.9014,
#   'T1': 34.419,
#   'Aux dim': 1971,
#   'NERI2': 31323,
#   'ERI2': 301.99,
#   'PivotRI-3index': 15.899,
#   'PivotRI-2index': 0.0028884,
#   'Trans-Cholesky': 0.012107,
#   'Trans-TriInv': 0.01356,
#   'Trans-Gemm': 0.17175,
#   'Trans-Copy': 0.10087,
#   'Trans': 0.29846,
#   'T2': 16.201,
#   'TotalT': 50.622},
#  ('1e-8', '1e-2', 500): {'NERI1': 29797,
#   'ERI1': 326.83,
#   'ERIvec': 27.043,
#   'ERIcopy': 0.029445,
#   'ERItrans': 0.022861,
#   'CDalgMM': 0.12477,
#   'CDalgMV': 0.083648,
#   'Shrink count': 17,
#   'Shrink': 0.96893,
#   'misc': 2.7871,
#   'T1': 31.06,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.69,
#   'PivotRI-3index': 15.709,
#   'PivotRI-2index': 0.0018657,
#   'Trans-Cholesky': 0.016506,
#   'Trans-TriInv': 0.013171,
#   'Trans-Gemm': 0.15063,
#   'Trans-Copy': 0.12767,
#   'Trans': 0.30818,
#   'T2': 16.02,
#   'TotalT': 47.082},
#  ('1e-8', '1e-2', 2000): {'NERI1': 34281,
#   'ERI1': 355.92,
#   'ERIvec': 34.574,
#   'ERIcopy': 0.056014,
#   'ERItrans': 0.020719,
#   'CDalgMM': 0.1921,
#   'CDalgMV': 0.10485,
#   'Shrink count': 8,
#   'Shrink': 0.7127,
#   'misc': 2.8969,
#   'T1': 38.557,
#   'Aux dim': 1970,
#   'NERI2': 31440,
#   'ERI2': 302.07,
#   'PivotRI-3index': 15.738,
#   'PivotRI-2index': 0.0023659,
#   'Trans-Cholesky': 0.0094195,
#   'Trans-TriInv': 0.012744,
#   'Trans-Gemm': 0.14528,
#   'Trans-Copy': 0.09222,
#   'Trans': 0.25985,
#   'T2': 16.001,
#   'TotalT': 54.559},
#  ('1e-8', '1e-2', 200): {'NERI1': 28462,
#   'ERI1': 322.22,
#   'ERIvec': 23.294,
#   'ERIcopy': 0.027146,
#   'ERItrans': 0.02658,
#   'CDalgMM': 0.15083,
#   'CDalgMV': 0.080395,
#   'Shrink count': 30,
#   'Shrink': 1.5769,
#   'misc': 2.9048,
#   'T1': 28.06,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.59,
#   'PivotRI-3index': 15.551,
#   'PivotRI-2index': 0.0034521,
#   'Trans-Cholesky': 0.013791,
#   'Trans-TriInv': 0.015937,
#   'Trans-Gemm': 0.19984,
#   'Trans-Copy': 0.10743,
#   'Trans': 0.33718,
#   'T2': 15.891,
#   'TotalT': 43.953},
#  ('1e-8', '1e-2', 5000): {'NERI1': 36690,
#   'ERI1': 352.99,
#   'ERIvec': 34.87,
#   'ERIcopy': 0.072026,
#   'ERItrans': 0.017978,
#   'CDalgMM': 0.23049,
#   'CDalgMV': 0.13007,
#   'Shrink count': 5,
#   'Shrink': 0.52942,
#   'misc': 2.8005,
#   'T1': 38.651,
#   'Aux dim': 1971,
#   'NERI2': 31323,
#   'ERI2': 301.34,
#   'PivotRI-3index': 15.482,
#   'PivotRI-2index': 0.0021136,
#   'Trans-Cholesky': 0.010853,
#   'Trans-TriInv': 0.013724,
#   'Trans-Gemm': 0.14768,
#   'Trans-Copy': 0.097582,
#   'Trans': 0.26998,
#   'T2': 15.755,
#   'TotalT': 54.409},
#  ('1e-8', '1e-2', 100): {'NERI1': 28011,
#   'ERI1': 317.6,
#   'ERIvec': 23.133,
#   'ERIcopy': 0.016683,
#   'ERItrans': 0.025284,
#   'CDalgMM': 0.1324,
#   'CDalgMV': 0.079252,
#   'Shrink count': 47,
#   'Shrink': 2.1729,
#   'misc': 2.7986,
#   'T1': 28.358,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.52,
#   'PivotRI-3index': 15.764,
#   'PivotRI-2index': 0.0043724,
#   'Trans-Cholesky': 0.011222,
#   'Trans-TriInv': 0.015292,
#   'Trans-Gemm': 0.24572,
#   'Trans-Copy': 0.10002,
#   'Trans': 0.37244,
#   'T2': 16.141,
#   'TotalT': 44.503},
#  ('1e-8', '1e-2', 50): {'NERI1': 27002,
#   'ERI1': 313.05,
#   'ERIvec': 20.336,
#   'ERIcopy': 0.024248,
#   'ERItrans': 0.031024,
#   'CDalgMM': 0.17759,
#   'CDalgMV': 0.075685,
#   'Shrink count': 80,
#   'Shrink': 3.5833,
#   'misc': 2.8974,
#   'T1': 27.125,
#   'Aux dim': 1970,
#   'NERI2': 31323,
#   'ERI2': 301.66,
#   'PivotRI-3index': 15.665,
#   'PivotRI-2index': 0.0070394,
#   'Trans-Cholesky': 0.0087729,
#   'Trans-TriInv': 0.01172,
#   'Trans-Gemm': 0.15217,
#   'Trans-Copy': 0.098633,
#   'Trans': 0.27148,
#   'T2': 15.944,
#   'TotalT': 43.072},
#  ('1e-8', '1e-2', 20): {'NERI1': 26778,
#   'ERI1': 310.89,
#   'ERIvec': 18.281,
#   'ERIcopy': 0.053389,
#   'ERItrans': 0.032295,
#   'CDalgMM': 0.28086,
#   'CDalgMV': 0.075338,
#   'Shrink count': 168,
#   'Shrink': 7.5788,
#   'misc': 2.7527,
#   'T1': 29.055,
#   'Aux dim': 1972,
#   'NERI2': 31440,
#   'ERI2': 301.85,
#   'PivotRI-3index': 15.512,
#   'PivotRI-2index': 0.0018045,
#   'Trans-Cholesky': 0.013657,
#   'Trans-TriInv': 0.013183,
#   'Trans-Gemm': 0.16349,
#   'Trans-Copy': 0.084543,
#   'Trans': 0.27507,
#   'T2': 15.789,
#   'TotalT': 44.845},
#  ('1e-8', '1e-2', 1): {'NERI1': 26437,
#   'ERI1': 306.99,
#   'ERIvec': 18.697,
#   'ERIcopy': 0.061016,
#   'ERItrans': 0.043983,
#   'CDalgMM': 3.2699,
#   'CDalgMV': 0.061522,
#   'Shrink count': 1970,
#   'Shrink': 82.765,
#   'misc': 3.1083,
#   'T1': 108.01,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 302.16,
#   'PivotRI-3index': 15.517,
#   'PivotRI-2index': 0.010238,
#   'Trans-Cholesky': 0.019506,
#   'Trans-TriInv': 0.012545,
#   'Trans-Gemm': 0.16564,
#   'Trans-Copy': 0.11704,
#   'Trans': 0.31497,
#   'T2': 15.842,
#   'TotalT': 123.85},
#  ('1e-8', '1e-2', 20000): {'NERI1': 37044,
#   'ERI1': 354.11,
#   'ERIvec': 34.994,
#   'ERIcopy': 0.08875,
#   'ERItrans': 0.018797,
#   'CDalgMM': 0.28899,
#   'CDalgMV': 0.1488,
#   'Shrink count': 4,
#   'Shrink': 0.50853,
#   'misc': 3.1025,
#   'T1': 39.151,
#   'Aux dim': 1971,
#   'NERI2': 31323,
#   'ERI2': 301.3,
#   'PivotRI-3index': 15.965,
#   'PivotRI-2index': 0.0045961,
#   'Trans-Cholesky': 0.02042,
#   'Trans-TriInv': 0.01588,
#   'Trans-Gemm': 0.16457,
#   'Trans-Copy': 0.093528,
#   'Trans': 0.29459,
#   'T2': 16.264,
#   'TotalT': 55.417},
#  ('1e-8', '5e-3', 1000): {'NERI1': 31457,
#   'ERI1': 330.04,
#   'ERIvec': 25.481,
#   'ERIcopy': 0.046157,
#   'ERItrans': 0.023762,
#   'CDalgMM': 0.15656,
#   'CDalgMV': 0.09634,
#   'Shrink count': 11,
#   'Shrink': 0.83494,
#   'misc': 2.8062,
#   'T1': 29.445,
#   'Aux dim': 1972,
#   'NERI2': 31556,
#   'ERI2': 301.91,
#   'PivotRI-3index': 15.88,
#   'PivotRI-2index': 0.0043757,
#   'Trans-Cholesky': 0.013543,
#   'Trans-TriInv': 0.01485,
#   'Trans-Gemm': 0.2506,
#   'Trans-Copy': 0.094313,
#   'Trans': 0.37346,
#   'T2': 16.258,
#   'TotalT': 45.706},
#  ('1e-8', '5e-3', 500): {'NERI1': 30026,
#   'ERI1': 324.62,
#   'ERIvec': 24.034,
#   'ERIcopy': 0.035457,
#   'ERItrans': 0.030389,
#   'CDalgMM': 0.13271,
#   'CDalgMV': 0.082059,
#   'Shrink count': 17,
#   'Shrink': 0.95661,
#   'misc': 2.765,
#   'T1': 28.036,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 301.85,
#   'PivotRI-3index': 15.511,
#   'PivotRI-2index': 0.0018131,
#   'Trans-Cholesky': 0.0095202,
#   'Trans-TriInv': 0.013288,
#   'Trans-Gemm': 0.16447,
#   'Trans-Copy': 0.09871,
#   'Trans': 0.28617,
#   'T2': 15.8,
#   'TotalT': 43.837},
#  ('1e-8', '5e-3', 2000): {'NERI1': 34425,
#   'ERI1': 333.71,
#   'ERIvec': 28.7,
#   'ERIcopy': 0.064026,
#   'ERItrans': 0.031815,
#   'CDalgMM': 0.2192,
#   'CDalgMV': 0.12098,
#   'Shrink count': 8,
#   'Shrink': 0.78292,
#   'misc': 2.8048,
#   'T1': 32.724,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.77,
#   'PivotRI-3index': 15.625,
#   'PivotRI-2index': 0.0042526,
#   'Trans-Cholesky': 0.010981,
#   'Trans-TriInv': 0.018257,
#   'Trans-Gemm': 0.17469,
#   'Trans-Copy': 0.10255,
#   'Trans': 0.30669,
#   'T2': 15.936,
#   'TotalT': 48.663},
#  ('1e-8', '5e-3', 200): {'NERI1': 28454,
#   'ERI1': 323.1,
#   'ERIvec': 24.012,
#   'ERIcopy': 0.022794,
#   'ERItrans': 0.022434,
#   'CDalgMM': 0.14507,
#   'CDalgMV': 0.080054,
#   'Shrink count': 30,
#   'Shrink': 1.5243,
#   'misc': 2.9463,
#   'T1': 28.753,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.65,
#   'PivotRI-3index': 15.579,
#   'PivotRI-2index': 0.025719,
#   'Trans-Cholesky': 0.034095,
#   'Trans-TriInv': 0.039457,
#   'Trans-Gemm': 0.15886,
#   'Trans-Copy': 0.099655,
#   'Trans': 0.33223,
#   'T2': 15.937,
#   'TotalT': 44.694},
#  ('1e-8', '5e-3', 5000): {'NERI1': 36856,
#   'ERI1': 335.69,
#   'ERIvec': 28.401,
#   'ERIcopy': 0.06927,
#   'ERItrans': 0.02992,
#   'CDalgMM': 0.24645,
#   'CDalgMV': 0.15299,
#   'Shrink count': 4,
#   'Shrink': 0.57563,
#   'misc': 2.8429,
#   'T1': 32.318,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.8,
#   'PivotRI-3index': 15.752,
#   'PivotRI-2index': 0.0030043,
#   'Trans-Cholesky': 0.016194,
#   'Trans-TriInv': 0.012608,
#   'Trans-Gemm': 0.24939,
#   'Trans-Copy': 0.10035,
#   'Trans': 0.37876,
#   'T2': 16.134,
#   'TotalT': 48.455},
#  ('1e-8', '5e-3', 100): {'NERI1': 28011,
#   'ERI1': 320.15,
#   'ERIvec': 23.37,
#   'ERIcopy': 0.016935,
#   'ERItrans': 0.034469,
#   'CDalgMM': 0.12942,
#   'CDalgMV': 0.075427,
#   'Shrink count': 47,
#   'Shrink': 2.1402,
#   'misc': 2.9396,
#   'T1': 28.706,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.72,
#   'PivotRI-3index': 15.764,
#   'PivotRI-2index': 0.0034318,
#   'Trans-Cholesky': 0.010824,
#   'Trans-TriInv': 0.013192,
#   'Trans-Gemm': 0.19107,
#   'Trans-Copy': 0.095865,
#   'Trans': 0.31117,
#   'T2': 16.079,
#   'TotalT': 44.788},
#  ('1e-8', '5e-3', 50): {'NERI1': 27002,
#   'ERI1': 312.66,
#   'ERIvec': 20.479,
#   'ERIcopy': 0.01764,
#   'ERItrans': 0.028516,
#   'CDalgMM': 0.17779,
#   'CDalgMV': 0.074024,
#   'Shrink count': 80,
#   'Shrink': 3.5567,
#   'misc': 2.7805,
#   'T1': 27.114,
#   'Aux dim': 1970,
#   'NERI2': 31323,
#   'ERI2': 301.83,
#   'PivotRI-3index': 15.518,
#   'PivotRI-2index': 0.0055683,
#   'Trans-Cholesky': 0.0091469,
#   'Trans-TriInv': 0.012027,
#   'Trans-Gemm': 0.15487,
#   'Trans-Copy': 0.090979,
#   'Trans': 0.26719,
#   'T2': 15.791,
#   'TotalT': 42.908},
#  ('1e-8', '5e-3', 20): {'NERI1': 26778,
#   'ERI1': 310.26,
#   'ERIvec': 18.345,
#   'ERIcopy': 0.018405,
#   'ERItrans': 0.02943,
#   'CDalgMM': 0.27232,
#   'CDalgMV': 0.072862,
#   'Shrink count': 168,
#   'Shrink': 7.548,
#   'misc': 2.7809,
#   'T1': 29.066,
#   'Aux dim': 1972,
#   'NERI2': 31440,
#   'ERI2': 301.63,
#   'PivotRI-3index': 15.592,
#   'PivotRI-2index': 0.0024973,
#   'Trans-Cholesky': 0.018925,
#   'Trans-TriInv': 0.013473,
#   'Trans-Gemm': 0.24275,
#   'Trans-Copy': 0.11364,
#   'Trans': 0.38899,
#   'T2': 15.983,
#   'TotalT': 45.053},
#  ('1e-8', '5e-3', 1): {'NERI1': 26437,
#   'ERI1': 306.59,
#   'ERIvec': 18.433,
#   'ERIcopy': 0.061736,
#   'ERItrans': 0.038111,
#   'CDalgMM': 2.985,
#   'CDalgMV': 0.063172,
#   'Shrink count': 1970,
#   'Shrink': 81.254,
#   'misc': 2.9352,
#   'T1': 105.77,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 302.21,
#   'PivotRI-3index': 15.668,
#   'PivotRI-2index': 0.0028477,
#   'Trans-Cholesky': 0.020692,
#   'Trans-TriInv': 0.012663,
#   'Trans-Gemm': 0.15066,
#   'Trans-Copy': 0.10848,
#   'Trans': 0.29279,
#   'T2': 15.964,
#   'TotalT': 121.74},
#  ('1e-8', '5e-3', 20000): {'NERI1': 36906,
#   'ERI1': 335.03,
#   'ERIvec': 28.4,
#   'ERIcopy': 0.11706,
#   'ERItrans': 0.0317,
#   'CDalgMM': 0.24146,
#   'CDalgMV': 0.15478,
#   'Shrink count': 4,
#   'Shrink': 0.44976,
#   'misc': 2.8073,
#   'T1': 32.202,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.66,
#   'PivotRI-3index': 15.539,
#   'PivotRI-2index': 0.0017255,
#   'Trans-Cholesky': 0.010526,
#   'Trans-TriInv': 0.014429,
#   'Trans-Gemm': 0.15599,
#   'Trans-Copy': 0.096657,
#   'Trans': 0.27776,
#   'T2': 15.818,
#   'TotalT': 48.023},
#  ('1e-8', '1e-3', 1000): {'NERI1': 32079,
#   'ERI1': 328.21,
#   'ERIvec': 25.569,
#   'ERIcopy': 0.040411,
#   'ERItrans': 0.027389,
#   'CDalgMM': 0.15514,
#   'CDalgMV': 0.092469,
#   'Shrink count': 11,
#   'Shrink': 0.74027,
#   'misc': 2.8338,
#   'T1': 29.458,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 302.51,
#   'PivotRI-3index': 15.702,
#   'PivotRI-2index': 0.0038365,
#   'Trans-Cholesky': 0.01467,
#   'Trans-TriInv': 0.013548,
#   'Trans-Gemm': 0.17628,
#   'Trans-Copy': 0.12199,
#   'Trans': 0.32664,
#   'T2': 16.033,
#   'TotalT': 45.494},
#  ('1e-8', '1e-3', 500): {'NERI1': 30265,
#   'ERI1': 329.16,
#   'ERIvec': 24.426,
#   'ERIcopy': 0.02827,
#   'ERItrans': 0.022672,
#   'CDalgMM': 0.126,
#   'CDalgMV': 0.083273,
#   'Shrink count': 16,
#   'Shrink': 0.89585,
#   'misc': 2.8239,
#   'T1': 28.406,
#   'Aux dim': 1970,
#   'NERI2': 31440,
#   'ERI2': 301.47,
#   'PivotRI-3index': 15.817,
#   'PivotRI-2index': 0.0031798,
#   'Trans-Cholesky': 0.010959,
#   'Trans-TriInv': 0.018197,
#   'Trans-Gemm': 0.1645,
#   'Trans-Copy': 0.10932,
#   'Trans': 0.30315,
#   'T2': 16.124,
#   'TotalT': 44.534},
#  ('1e-8', '1e-3', 2000): {'NERI1': 34623,
#   'ERI1': 330.55,
#   'ERIvec': 25.498,
#   'ERIcopy': 0.064212,
#   'ERItrans': 0.026537,
#   'CDalgMM': 0.20063,
#   'CDalgMV': 0.10209,
#   'Shrink count': 7,
#   'Shrink': 0.62277,
#   'misc': 2.9449,
#   'T1': 29.459,
#   'Aux dim': 1972,
#   'NERI2': 31556,
#   'ERI2': 301.7,
#   'PivotRI-3index': 15.522,
#   'PivotRI-2index': 0.0019397,
#   'Trans-Cholesky': 0.014907,
#   'Trans-TriInv': 0.01319,
#   'Trans-Gemm': 0.16314,
#   'Trans-Copy': 0.11779,
#   'Trans': 0.30921,
#   'T2': 15.833,
#   'TotalT': 45.293},
#  ('1e-8', '1e-3', 200): {'NERI1': 28343,
#   'ERI1': 322.78,
#   'ERIvec': 24.172,
#   'ERIcopy': 0.027466,
#   'ERItrans': 0.024181,
#   'CDalgMM': 0.15022,
#   'CDalgMV': 0.17723,
#   'Shrink count': 30,
#   'Shrink': 1.5495,
#   'misc': 3.224,
#   'T1': 29.324,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 302.21,
#   'PivotRI-3index': 15.691,
#   'PivotRI-2index': 0.0031711,
#   'Trans-Cholesky': 0.01037,
#   'Trans-TriInv': 0.013531,
#   'Trans-Gemm': 0.22752,
#   'Trans-Copy': 0.11474,
#   'Trans': 0.36629,
#   'T2': 16.06,
#   'TotalT': 45.387},
#  ('1e-8', '1e-3', 5000): {'NERI1': 36636,
#   'ERI1': 335.05,
#   'ERIvec': 30.4,
#   'ERIcopy': 0.093354,
#   'ERItrans': 0.026668,
#   'CDalgMM': 0.28997,
#   'CDalgMV': 0.17484,
#   'Shrink count': 4,
#   'Shrink': 0.41955,
#   'misc': 3.1042,
#   'T1': 34.509,
#   'Aux dim': 1972,
#   'NERI2': 31556,
#   'ERI2': 302.29,
#   'PivotRI-3index': 15.589,
#   'PivotRI-2index': 0.0018852,
#   'Trans-Cholesky': 0.021259,
#   'Trans-TriInv': 0.016719,
#   'Trans-Gemm': 0.18451,
#   'Trans-Copy': 0.087201,
#   'Trans': 0.30988,
#   'T2': 15.901,
#   'TotalT': 50.411},
#  ('1e-8', '1e-3', 100): {'NERI1': 28011,
#   'ERI1': 317.23,
#   'ERIvec': 23.156,
#   'ERIcopy': 0.017975,
#   'ERItrans': 0.028849,
#   'CDalgMM': 0.13044,
#   'CDalgMV': 0.08001,
#   'Shrink count': 47,
#   'Shrink': 2.1626,
#   'misc': 2.7853,
#   'T1': 28.361,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.75,
#   'PivotRI-3index': 15.841,
#   'PivotRI-2index': 0.0023275,
#   'Trans-Cholesky': 0.0096562,
#   'Trans-TriInv': 0.013715,
#   'Trans-Gemm': 0.1613,
#   'Trans-Copy': 0.096178,
#   'Trans': 0.28105,
#   'T2': 16.125,
#   'TotalT': 44.489},
#  ('1e-8', '1e-3', 50): {'NERI1': 27002,
#   'ERI1': 313.18,
#   'ERIvec': 20.584,
#   'ERIcopy': 0.025028,
#   'ERItrans': 0.027015,
#   'CDalgMM': 0.20309,
#   'CDalgMV': 0.073191,
#   'Shrink count': 80,
#   'Shrink': 3.6821,
#   'misc': 2.7688,
#   'T1': 27.363,
#   'Aux dim': 1970,
#   'NERI2': 31323,
#   'ERI2': 301.3,
#   'PivotRI-3index': 15.661,
#   'PivotRI-2index': 0.0021654,
#   'Trans-Cholesky': 0.0088438,
#   'Trans-TriInv': 0.011973,
#   'Trans-Gemm': 0.15675,
#   'Trans-Copy': 0.083827,
#   'Trans': 0.26154,
#   'T2': 15.925,
#   'TotalT': 43.289},
#  ('1e-8', '1e-3', 20): {'NERI1': 26778,
#   'ERI1': 310.36,
#   'ERIvec': 18.049,
#   'ERIcopy': 0.018383,
#   'ERItrans': 0.029129,
#   'CDalgMM': 0.28488,
#   'CDalgMV': 0.075912,
#   'Shrink count': 168,
#   'Shrink': 7.6334,
#   'misc': 2.8372,
#   'T1': 28.928,
#   'Aux dim': 1972,
#   'NERI2': 31440,
#   'ERI2': 301.82,
#   'PivotRI-3index': 15.516,
#   'PivotRI-2index': 0.0021199,
#   'Trans-Cholesky': 0.018558,
#   'Trans-TriInv': 0.021241,
#   'Trans-Gemm': 0.19551,
#   'Trans-Copy': 0.088666,
#   'Trans': 0.32419,
#   'T2': 15.843,
#   'TotalT': 44.773},
#  ('1e-8', '1e-3', 1): {'NERI1': 26437,
#   'ERI1': 305.91,
#   'ERIvec': 18.389,
#   'ERIcopy': 0.061356,
#   'ERItrans': 0.044441,
#   'CDalgMM': 2.82,
#   'CDalgMV': 0.057559,
#   'Shrink count': 1970,
#   'Shrink': 80.473,
#   'misc': 2.9588,
#   'T1': 104.8,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 301.82,
#   'PivotRI-3index': 15.804,
#   'PivotRI-2index': 0.0030877,
#   'Trans-Cholesky': 0.01789,
#   'Trans-TriInv': 0.013144,
#   'Trans-Gemm': 0.14807,
#   'Trans-Copy': 0.10234,
#   'Trans': 0.28169,
#   'T2': 16.089,
#   'TotalT': 120.9},
#  ('1e-8', '1e-3', 20000): {'NERI1': 37968,
#   'ERI1': 335.15,
#   'ERIvec': 24.847,
#   'ERIcopy': 0.13063,
#   'ERItrans': 0.024065,
#   'CDalgMM': 0.22493,
#   'CDalgMV': 0.31518,
#   'Shrink count': 3,
#   'Shrink': 0.33884,
#   'misc': 3.0381,
#   'T1': 28.919,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.43,
#   'PivotRI-3index': 15.528,
#   'PivotRI-2index': 0.0057354,
#   'Trans-Cholesky': 0.016147,
#   'Trans-TriInv': 0.012841,
#   'Trans-Gemm': 0.15869,
#   'Trans-Copy': 0.1095,
#   'Trans': 0.29737,
#   'T2': 15.832,
#   'TotalT': 44.752},
#  ('1e-8', '5e-4', 1000): {'NERI1': 32399,
#   'ERI1': 326.93,
#   'ERIvec': 24.705,
#   'ERIcopy': 0.039753,
#   'ERItrans': 0.021277,
#   'CDalgMM': 0.1508,
#   'CDalgMV': 0.10553,
#   'Shrink count': 10,
#   'Shrink': 0.75559,
#   'misc': 2.8734,
#   'T1': 28.651,
#   'Aux dim': 1971,
#   'NERI2': 31323,
#   'ERI2': 301.47,
#   'PivotRI-3index': 15.515,
#   'PivotRI-2index': 0.002651,
#   'Trans-Cholesky': 0.0097412,
#   'Trans-TriInv': 0.013241,
#   'Trans-Gemm': 0.1561,
#   'Trans-Copy': 0.10182,
#   'Trans': 0.28106,
#   'T2': 15.799,
#   'TotalT': 44.453},
#  ('1e-8', '5e-4', 500): {'NERI1': 30265,
#   'ERI1': 327.63,
#   'ERIvec': 24.327,
#   'ERIcopy': 0.034189,
#   'ERItrans': 0.022767,
#   'CDalgMM': 0.13398,
#   'CDalgMV': 0.084223,
#   'Shrink count': 16,
#   'Shrink': 0.91483,
#   'misc': 3.0463,
#   'T1': 28.563,
#   'Aux dim': 1970,
#   'NERI2': 31440,
#   'ERI2': 301.95,
#   'PivotRI-3index': 15.529,
#   'PivotRI-2index': 0.002547,
#   'Trans-Cholesky': 0.016208,
#   'Trans-TriInv': 0.015164,
#   'Trans-Gemm': 0.17529,
#   'Trans-Copy': 0.097309,
#   'Trans': 0.30422,
#   'T2': 15.836,
#   'TotalT': 44.4},
#  ('1e-8', '5e-4', 2000): {'NERI1': 33888,
#   'ERI1': 329.61,
#   'ERIvec': 25.445,
#   'ERIcopy': 0.051568,
#   'ERItrans': 0.024136,
#   'CDalgMM': 0.18812,
#   'CDalgMV': 0.10147,
#   'Shrink count': 7,
#   'Shrink': 0.57744,
#   'misc': 3.0608,
#   'T1': 29.448,
#   'Aux dim': 1970,
#   'NERI2': 31440,
#   'ERI2': 302.06,
#   'PivotRI-3index': 15.565,
#   'PivotRI-2index': 0.0036738,
#   'Trans-Cholesky': 0.0098662,
#   'Trans-TriInv': 0.012557,
#   'Trans-Gemm': 0.1676,
#   'Trans-Copy': 0.088338,
#   'Trans': 0.27857,
#   'T2': 15.847,
#   'TotalT': 45.298},
#  ('1e-8', '5e-4', 200): {'NERI1': 28343,
#   'ERI1': 323.29,
#   'ERIvec': 24.383,
#   'ERIcopy': 0.063179,
#   'ERItrans': 0.024532,
#   'CDalgMM': 0.14453,
#   'CDalgMV': 0.086764,
#   'Shrink count': 30,
#   'Shrink': 1.4797,
#   'misc': 2.8105,
#   'T1': 28.992,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 301.96,
#   'PivotRI-3index': 15.541,
#   'PivotRI-2index': 0.0027453,
#   'Trans-Cholesky': 0.0092322,
#   'Trans-TriInv': 0.013186,
#   'Trans-Gemm': 0.15136,
#   'Trans-Copy': 0.098539,
#   'Trans': 0.27252,
#   'T2': 15.816,
#   'TotalT': 44.812},
#  ('1e-8', '5e-4', 5000): {'NERI1': 36246,
#   'ERI1': 330.66,
#   'ERIvec': 26.77,
#   'ERIcopy': 0.081451,
#   'ERItrans': 0.033847,
#   'CDalgMM': 0.23684,
#   'CDalgMV': 0.23292,
#   'Shrink count': 4,
#   'Shrink': 0.43399,
#   'misc': 2.9372,
#   'T1': 30.726,
#   'Aux dim': 1973,
#   'NERI2': 31556,
#   'ERI2': 301.64,
#   'PivotRI-3index': 15.548,
#   'PivotRI-2index': 0.0026163,
#   'Trans-Cholesky': 0.017423,
#   'Trans-TriInv': 0.012865,
#   'Trans-Gemm': 0.16013,
#   'Trans-Copy': 0.11219,
#   'Trans': 0.30282,
#   'T2': 15.854,
#   'TotalT': 46.581},
#  ('1e-8', '5e-4', 100): {'NERI1': 28011,
#   'ERI1': 318.1,
#   'ERIvec': 23.539,
#   'ERIcopy': 0.017306,
#   'ERItrans': 0.02684,
#   'CDalgMM': 0.1267,
#   'CDalgMV': 0.079659,
#   'Shrink count': 47,
#   'Shrink': 2.1499,
#   'misc': 2.9402,
#   'T1': 28.879,
#   'Aux dim': 1971,
#   'NERI2': 31440,
#   'ERI2': 301.56,
#   'PivotRI-3index': 16.008,
#   'PivotRI-2index': 0.0038858,
#   'Trans-Cholesky': 0.010034,
#   'Trans-TriInv': 0.013879,
#   'Trans-Gemm': 0.15792,
#   'Trans-Copy': 0.10311,
#   'Trans': 0.28513,
#   'T2': 16.297,
#   'TotalT': 45.179},
#  ('1e-8', '5e-4', 50): {'NERI1': 27002,
#   'ERI1': 313.08,
#   'ERIvec': 20.531,
#   'ERIcopy': 0.017922,
#   'ERItrans': 0.028419,
#   'CDalgMM': 0.1758,
#   'CDalgMV': 0.075418,
#   'Shrink count': 80,
#   'Shrink': 3.5544,
#   'misc': 2.8004,
#   'T1': 27.183,
#   'Aux dim': 1970,
#   'NERI2': 31323,
#   'ERI2': 301.55,
#   'PivotRI-3index': 15.696,
#   'PivotRI-2index': 0.013787,
#   'Trans-Cholesky': 0.0089645,
#   'Trans-TriInv': 0.011045,
#   'Trans-Gemm': 0.15878,
#   'Trans-Copy': 0.088869,
#   'Trans': 0.26781,
#   'T2': 15.978,
#   'TotalT': 43.164},
#  ('1e-8', '5e-4', 20): {'NERI1': 26778,
#   'ERI1': 309.97,
#   'ERIvec': 18.192,
#   'ERIcopy': 0.014203,
#   'ERItrans': 0.030668,
#   'CDalgMM': 0.24243,
#   'CDalgMV': 0.075488,
#   'Shrink count': 168,
#   'Shrink': 7.3258,
#   'misc': 2.7738,
#   'T1': 28.654,
#   'Aux dim': 1972,
#   'NERI2': 31440,
#   'ERI2': 302.08,
#   'PivotRI-3index': 16.154,
#   'PivotRI-2index': 0.0024403,
#   'Trans-Cholesky': 0.031741,
#   'Trans-TriInv': 0.012511,
#   'Trans-Gemm': 0.15195,
#   'Trans-Copy': 0.089403,
#   'Trans': 0.28582,
#   'T2': 16.442,
#   'TotalT': 45.099},
#  ('1e-8', '5e-4', 1): {'NERI1': 26437,
#   'ERI1': 306.29,
#   'ERIvec': 18.504,
#   'ERIcopy': 0.061522,
#   'ERItrans': 0.038034,
#   'CDalgMM': 3.037,
#   'CDalgMV': 0.057487,
#   'Shrink count': 1970,
#   'Shrink': 80.71,
#   'misc': 3.7386,
#   'T1': 106.15,
#   'Aux dim': 1971,
#   'NERI2': 31556,
#   'ERI2': 301.68,
#   'PivotRI-3index': 15.522,
#   'PivotRI-2index': 0.0027882,
#   'Trans-Cholesky': 0.019441,
#   'Trans-TriInv': 0.015416,
#   'Trans-Gemm': 0.24261,
#   'Trans-Copy': 0.10187,
#   'Trans': 0.37955,
#   'T2': 15.904,
#   'TotalT': 122.05},
#  ('1e-8', '5e-4', 20000): {'NERI1': 37620,
#   'ERI1': 331.92,
#   'ERIvec': 26.233,
#   'ERIcopy': 0.10285,
#   'ERItrans': 0.034106,
#   'CDalgMM': 0.20355,
#   'CDalgMV': 0.28229,
#   'Shrink count': 2,
#   'Shrink': 0.29621,
#   'misc': 2.9903,
#   'T1': 30.142,
#   'Aux dim': 1970,
#   'NERI2': 31440,
#   'ERI2': 301.87,
#   'PivotRI-3index': 15.606,
#   'PivotRI-2index': 0.0084917,
#   'Trans-Cholesky': 0.01682,
#   'Trans-TriInv': 0.010658,
#   'Trans-Gemm': 0.15085,
#   'Trans-Copy': 0.10921,
#   'Trans': 0.28774,
#   'T2': 15.903,
#   'TotalT': 46.048},
#  ('1e-6', '1e-1', 1000): {'NERI1': 25628,
#   'ERI1': 310.53,
#   'ERIvec': 19.678,
#   'ERIcopy': 0.02192,
#   'ERItrans': 0.040414,
#   'CDalgMM': 0.10181,
#   'CDalgMV': 0.055955,
#   'Shrink count': 9,
#   'Shrink': 0.38598,
#   'misc': 2.6795,
#   'T1': 22.964,
#   'Aux dim': 1321,
#   'NERI2': 20081,
#   'ERI2': 268.27,
#   'PivotRI-3index': 14.381,
#   'PivotRI-2index': 0.0041771,
#   'Trans-Cholesky': 0.004771,
#   'Trans-TriInv': 0.0050117,
#   'Trans-Gemm': 0.079551,
#   'Trans-Copy': 0.064321,
#   'Trans': 0.15379,
#   'T2': 14.539,
#   'TotalT': 37.504},
#  ('1e-6', '1e-1', 500): {'NERI1': 22776,
#   'ERI1': 305.58,
#   'ERIvec': 20.098,
#   'ERIcopy': 0.014425,
#   'ERItrans': 0.011902,
#   'CDalgMM': 0.06776,
#   'CDalgMV': 0.05806,
#   'Shrink count': 12,
#   'Shrink': 0.44065,
#   'misc': 2.6738,
#   'T1': 23.364,
#   'Aux dim': 1321,
#   'NERI2': 20081,
#   'ERI2': 269.13,
#   'PivotRI-3index': 14.269,
#   'PivotRI-2index': 0.0016764,
#   'Trans-Cholesky': 0.0058248,
#   'Trans-TriInv': 0.007673,
#   'Trans-Gemm': 0.10859,
#   'Trans-Copy': 0.065498,
#   'Trans': 0.18772,
#   'T2': 14.459,
#   'TotalT': 37.824},
#  ('1e-6', '1e-1', 2000): {'NERI1': 28325,
#   'ERI1': 315.98,
#   'ERIvec': 22.312,
#   'ERIcopy': 0.023737,
#   'ERItrans': 0.019174,
#   'CDalgMM': 0.075162,
#   'CDalgMV': 0.071144,
#   'Shrink count': 7,
#   'Shrink': 0.50364,
#   'misc': 2.7363,
#   'T1': 25.741,
#   'Aux dim': 1321,
#   'NERI2': 20081,
#   'ERI2': 267.9,
#   'PivotRI-3index': 14.222,
#   'PivotRI-2index': 0.031789,
#   'Trans-Cholesky': 0.050888,
#   'Trans-TriInv': 0.004035,
#   'Trans-Gemm': 0.10902,
#   'Trans-Copy': 0.062445,
#   'Trans': 0.22649,
#   'T2': 14.481,
#   'TotalT': 40.223},
#  ('1e-6', '1e-1', 200): {'NERI1': 21985,
#   'ERI1': 302.58,
#   'ERIvec': 20.036,
#   'ERIcopy': 0.013241,
#   'ERItrans': 0.011996,
#   'CDalgMM': 0.066765,
#   'CDalgMV': 0.049044,
#   'Shrink count': 20,
#   'Shrink': 0.70911,
#   'misc': 2.6933,
#   'T1': 23.579,
#   'Aux dim': 1321,
#   'NERI2': 20081,
#   'ERI2': 268.28,
#   'PivotRI-3index': 14.212,
#   'PivotRI-2index': 0.0021502,
#   'Trans-Cholesky': 0.0042208,
#   'Trans-TriInv': 0.0061316,
#   'Trans-Gemm': 0.080194,
#   'Trans-Copy': 0.060412,
#   'Trans': 0.15108,
#   'T2': 14.366,
#   'TotalT': 37.949},
#  ('1e-6', '1e-1', 5000): {'NERI1': 28325,
#   'ERI1': 316.72,
#   'ERIvec': 22.253,
#   'ERIcopy': 0.031002,
#   'ERItrans': 0.020736,
#   'CDalgMM': 0.083828,
#   'CDalgMV': 0.067717,
#   'Shrink count': 7,
#   'Shrink': 0.3813,
#   'misc': 2.7254,
#   'T1': 25.563,
#   'Aux dim': 1321,
#   'NERI2': 20081,
#   'ERI2': 268.08,
#   'PivotRI-3index': 14.234,
#   'PivotRI-2index': 0.0012206,
#   'Trans-Cholesky': 0.0072161,
#   'Trans-TriInv': 0.0059942,
#   'Trans-Gemm': 0.13115,
#   'Trans-Copy': 0.07961,
#   'Trans': 0.22413,
#   'T2': 14.459,
#   'TotalT': 40.026},
#  ('1e-6', '1e-1', 100): {'NERI1': 19720,
#   'ERI1': 291.07,
#   'ERIvec': 18.419,
#   'ERIcopy': 0.010091,
#   'ERItrans': 0.011979,
#   'CDalgMM': 0.068666,
#   'CDalgMV': 0.04629,
#   'Shrink count': 32,
#   'Shrink': 1.0249,
#   'misc': 2.6949,
#   'T1': 22.275,
#   'Aux dim': 1321,
#   'NERI2': 20081,
#   'ERI2': 268.27,
#   'PivotRI-3index': 14.226,
#   'PivotRI-2index': 0.0019672,
#   'Trans-Cholesky': 0.0069391,
#   'Trans-TriInv': 0.011018,
#   'Trans-Gemm': 0.083649,
#   'Trans-Copy': 0.065736,
#   'Trans': 0.16749,
#   'T2': 14.396,
#   'TotalT': 36.675},
#  ('1e-6', '1e-1', 50): {'NERI1': 18112,
#   'ERI1': 279.51,
#   'ERIvec': 16.736,
#   'ERIcopy': 0.0090423,
#   'ERItrans': 0.012545,
#   'CDalgMM': 0.09905,
#   'CDalgMV': 0.045899,
#   'Shrink count': 52,
#   'Shrink': 1.7812,
#   'misc': 2.8517,
#   'T1': 21.536,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.83,
#   'PivotRI-3index': 14.356,
#   'PivotRI-2index': 0.0030023,
#   'Trans-Cholesky': 0.0069273,
#   'Trans-TriInv': 0.0076697,
#   'Trans-Gemm': 0.10448,
#   'Trans-Copy': 0.082566,
#   'Trans': 0.2018,
#   'T2': 14.561,
#   'TotalT': 36.1},
#  ('1e-6', '1e-1', 20): {'NERI1': 17378,
#   'ERI1': 274.23,
#   'ERIvec': 15.957,
#   'ERIcopy': 0.015473,
#   'ERItrans': 0.014558,
#   'CDalgMM': 0.10789,
#   'CDalgMV': 0.045506,
#   'Shrink count': 110,
#   'Shrink': 3.5861,
#   'misc': 3.4624,
#   'T1': 23.189,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.65,
#   'PivotRI-3index': 14.147,
#   'PivotRI-2index': 0.0010861,
#   'Trans-Cholesky': 0.017454,
#   'Trans-TriInv': 0.005381,
#   'Trans-Gemm': 0.079979,
#   'Trans-Copy': 0.066487,
#   'Trans': 0.16949,
#   'T2': 14.318,
#   'TotalT': 37.508},
#  ('1e-6', '1e-1', 1): {'NERI1': 17076,
#   'ERI1': 264.81,
#   'ERIvec': 15.772,
#   'ERIcopy': 0.035904,
#   'ERItrans': 0.023482,
#   'CDalgMM': 1.296,
#   'CDalgMV': 0.037229,
#   'Shrink count': 1320,
#   'Shrink': 38.412,
#   'misc': 3.6843,
#   'T1': 59.262,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.53,
#   'PivotRI-3index': 14.57,
#   'PivotRI-2index': 0.00070508,
#   'Trans-Cholesky': 0.010585,
#   'Trans-TriInv': 0.0069842,
#   'Trans-Gemm': 0.10447,
#   'Trans-Copy': 0.082254,
#   'Trans': 0.20454,
#   'T2': 14.776,
#   'TotalT': 74.04},
#  ('1e-6', '1e-1', 20000): {'NERI1': 28325,
#   'ERI1': 316.47,
#   'ERIvec': 22.199,
#   'ERIcopy': 0.031589,
#   'ERItrans': 0.020112,
#   'CDalgMM': 0.073897,
#   'CDalgMV': 0.06698,
#   'Shrink count': 7,
#   'Shrink': 0.38471,
#   'misc': 2.692,
#   'T1': 25.469,
#   'Aux dim': 1321,
#   'NERI2': 20081,
#   'ERI2': 267.86,
#   'PivotRI-3index': 14.223,
#   'PivotRI-2index': 0.0025054,
#   'Trans-Cholesky': 0.0041792,
#   'Trans-TriInv': 0.0053351,
#   'Trans-Gemm': 0.077662,
#   'Trans-Copy': 0.066351,
#   'Trans': 0.15366,
#   'T2': 14.38,
#   'TotalT': 39.852},
#  ('1e-6', '5e-2', 1000): {'NERI1': 25909,
#   'ERI1': 319.09,
#   'ERIvec': 24.173,
#   'ERIcopy': 0.025724,
#   'ERItrans': 0.027142,
#   'CDalgMM': 0.062033,
#   'CDalgMV': 0.058184,
#   'Shrink count': 8,
#   'Shrink': 0.39666,
#   'misc': 2.6848,
#   'T1': 27.428,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.62,
#   'PivotRI-3index': 14.253,
#   'PivotRI-2index': 0.0010268,
#   'Trans-Cholesky': 0.0088022,
#   'Trans-TriInv': 0.0072222,
#   'Trans-Gemm': 0.089854,
#   'Trans-Copy': 0.076059,
#   'Trans': 0.18214,
#   'T2': 14.436,
#   'TotalT': 41.865},
#  ('1e-6', '5e-2', 500): {'NERI1': 22682,
#   'ERI1': 309.03,
#   'ERIvec': 22.267,
#   'ERIcopy': 0.01987,
#   'ERItrans': 0.013254,
#   'CDalgMM': 0.057152,
#   'CDalgMV': 0.05095,
#   'Shrink count': 12,
#   'Shrink': 0.44889,
#   'misc': 2.6873,
#   'T1': 25.545,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 270.01,
#   'PivotRI-3index': 14.328,
#   'PivotRI-2index': 0.0010078,
#   'Trans-Cholesky': 0.0086987,
#   'Trans-TriInv': 0.0060635,
#   'Trans-Gemm': 0.081537,
#   'Trans-Copy': 0.065334,
#   'Trans': 0.16178,
#   'T2': 14.491,
#   'TotalT': 40.038},
#  ('1e-6', '5e-2', 2000): {'NERI1': 30246,
#   'ERI1': 325.76,
#   'ERIvec': 27.746,
#   'ERIcopy': 0.027271,
#   'ERItrans': 0.019111,
#   'CDalgMM': 0.077215,
#   'CDalgMV': 0.069922,
#   'Shrink count': 6,
#   'Shrink': 0.50638,
#   'misc': 2.7288,
#   'T1': 31.175,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.44,
#   'PivotRI-3index': 14.519,
#   'PivotRI-2index': 0.0011058,
#   'Trans-Cholesky': 0.0056428,
#   'Trans-TriInv': 0.0055712,
#   'Trans-Gemm': 0.11197,
#   'Trans-Copy': 0.066161,
#   'Trans': 0.18949,
#   'T2': 14.709,
#   'TotalT': 45.888},
#  ('1e-6', '5e-2', 200): {'NERI1': 21683,
#   'ERI1': 301.65,
#   'ERIvec': 21.82,
#   'ERIcopy': 0.014022,
#   'ERItrans': 0.012814,
#   'CDalgMM': 0.066791,
#   'CDalgMV': 0.047533,
#   'Shrink count': 20,
#   'Shrink': 0.76713,
#   'misc': 2.7059,
#   'T1': 25.434,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.35,
#   'PivotRI-3index': 14.28,
#   'PivotRI-2index': 0.0014347,
#   'Trans-Cholesky': 0.0065369,
#   'Trans-TriInv': 0.0056577,
#   'Trans-Gemm': 0.092995,
#   'Trans-Copy': 0.066522,
#   'Trans': 0.17186,
#   'T2': 14.453,
#   'TotalT': 39.89},
#  ('1e-6', '5e-2', 5000): {'NERI1': 30828,
#   'ERI1': 326.11,
#   'ERIvec': 27.997,
#   'ERIcopy': 0.030508,
#   'ERItrans': 0.023912,
#   'CDalgMM': 0.11063,
#   'CDalgMV': 0.079178,
#   'Shrink count': 6,
#   'Shrink': 0.3805,
#   'misc': 2.9258,
#   'T1': 31.547,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.43,
#   'PivotRI-3index': 14.338,
#   'PivotRI-2index': 0.0017216,
#   'Trans-Cholesky': 0.0052808,
#   'Trans-TriInv': 0.0055737,
#   'Trans-Gemm': 0.083705,
#   'Trans-Copy': 0.093036,
#   'Trans': 0.18773,
#   'T2': 14.528,
#   'TotalT': 46.078},
#  ('1e-6', '5e-2', 100): {'NERI1': 19870,
#   'ERI1': 289.19,
#   'ERIvec': 18.368,
#   'ERIcopy': 0.011328,
#   'ERItrans': 0.012514,
#   'CDalgMM': 0.065287,
#   'CDalgMV': 0.067347,
#   'Shrink count': 32,
#   'Shrink': 1.0305,
#   'misc': 2.6378,
#   'T1': 22.192,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.48,
#   'PivotRI-3index': 14.476,
#   'PivotRI-2index': 0.013888,
#   'Trans-Cholesky': 0.0054963,
#   'Trans-TriInv': 0.0055634,
#   'Trans-Gemm': 0.082946,
#   'Trans-Copy': 0.06784,
#   'Trans': 0.16198,
#   'T2': 14.652,
#   'TotalT': 36.847},
#  ('1e-6', '5e-2', 50): {'NERI1': 18113,
#   'ERI1': 278.97,
#   'ERIvec': 17.09,
#   'ERIcopy': 0.012116,
#   'ERItrans': 0.015844,
#   'CDalgMM': 0.096536,
#   'CDalgMV': 0.055186,
#   'Shrink count': 53,
#   'Shrink': 1.7295,
#   'misc': 2.8173,
#   'T1': 21.816,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.53,
#   'PivotRI-3index': 14.34,
#   'PivotRI-2index': 0.0013589,
#   'Trans-Cholesky': 0.0051448,
#   'Trans-TriInv': 0.0095505,
#   'Trans-Gemm': 0.080722,
#   'Trans-Copy': 0.062615,
#   'Trans': 0.15817,
#   'T2': 14.5,
#   'TotalT': 36.317},
#  ('1e-6', '5e-2', 20): {'NERI1': 17427,
#   'ERI1': 273.61,
#   'ERIvec': 16.368,
#   'ERIcopy': 0.049319,
#   'ERItrans': 0.014256,
#   'CDalgMM': 0.096716,
#   'CDalgMV': 0.046246,
#   'Shrink count': 110,
#   'Shrink': 3.4669,
#   'misc': 2.7466,
#   'T1': 22.788,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.58,
#   'PivotRI-3index': 14.311,
#   'PivotRI-2index': 0.002165,
#   'Trans-Cholesky': 0.017141,
#   'Trans-TriInv': 0.0058042,
#   'Trans-Gemm': 0.077966,
#   'Trans-Copy': 0.077911,
#   'Trans': 0.17902,
#   'T2': 14.493,
#   'TotalT': 37.285},
#  ('1e-6', '5e-2', 1): {'NERI1': 17076,
#   'ERI1': 264.73,
#   'ERIvec': 15.773,
#   'ERIcopy': 0.037525,
#   'ERItrans': 0.018533,
#   'CDalgMM': 1.1996,
#   'CDalgMV': 0.03439,
#   'Shrink count': 1320,
#   'Shrink': 37.5,
#   'misc': 3.5159,
#   'T1': 58.079,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.25,
#   'PivotRI-3index': 14.273,
#   'PivotRI-2index': 0.0024845,
#   'Trans-Cholesky': 0.014284,
#   'Trans-TriInv': 0.0055427,
#   'Trans-Gemm': 0.079216,
#   'Trans-Copy': 0.078812,
#   'Trans': 0.17807,
#   'T2': 14.454,
#   'TotalT': 72.535},
#  ('1e-6', '5e-2', 20000): {'NERI1': 30828,
#   'ERI1': 328.11,
#   'ERIvec': 28.412,
#   'ERIcopy': 0.037642,
#   'ERItrans': 0.018647,
#   'CDalgMM': 0.095531,
#   'CDalgMV': 0.070862,
#   'Shrink count': 6,
#   'Shrink': 0.36316,
#   'misc': 2.7927,
#   'T1': 31.791,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.74,
#   'PivotRI-3index': 14.326,
#   'PivotRI-2index': 0.0030044,
#   'Trans-Cholesky': 0.0054347,
#   'Trans-TriInv': 0.0076144,
#   'Trans-Gemm': 0.11513,
#   'Trans-Copy': 0.067686,
#   'Trans': 0.19605,
#   'T2': 14.525,
#   'TotalT': 46.319},
#  ('1e-6', '1e-2', 1000): {'NERI1': 27039,
#   'ERI1': 317.6,
#   'ERIvec': 27.549,
#   'ERIcopy': 0.021468,
#   'ERItrans': 0.017102,
#   'CDalgMM': 0.05499,
#   'CDalgMV': 0.058235,
#   'Shrink count': 7,
#   'Shrink': 0.37966,
#   'misc': 2.7551,
#   'T1': 30.836,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 270.11,
#   'PivotRI-3index': 14.473,
#   'PivotRI-2index': 0.00090637,
#   'Trans-Cholesky': 0.0096181,
#   'Trans-TriInv': 0.0055577,
#   'Trans-Gemm': 0.121,
#   'Trans-Copy': 0.067274,
#   'Trans': 0.20363,
#   'T2': 14.677,
#   'TotalT': 45.516},
#  ('1e-6', '1e-2', 500): {'NERI1': 23438,
#   'ERI1': 308.37,
#   'ERIvec': 25.914,
#   'ERIcopy': 0.018105,
#   'ERItrans': 0.012926,
#   'CDalgMM': 0.055044,
#   'CDalgMV': 0.058469,
#   'Shrink count': 11,
#   'Shrink': 0.45606,
#   'misc': 2.7336,
#   'T1': 29.248,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.7,
#   'PivotRI-3index': 14.295,
#   'PivotRI-2index': 0.0016747,
#   'Trans-Cholesky': 0.004202,
#   'Trans-TriInv': 0.0062482,
#   'Trans-Gemm': 0.13052,
#   'Trans-Copy': 0.0686,
#   'Trans': 0.20976,
#   'T2': 14.507,
#   'TotalT': 43.757},
#  ('1e-6', '1e-2', 2000): {'NERI1': 30218,
#   'ERI1': 366.6,
#   'ERIvec': 39.975,
#   'ERIcopy': 0.060004,
#   'ERItrans': 0.014566,
#   'CDalgMM': 0.084294,
#   'CDalgMV': 0.067072,
#   'Shrink count': 5,
#   'Shrink': 0.35487,
#   'misc': 2.8014,
#   'T1': 43.358,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 270.14,
#   'PivotRI-3index': 14.323,
#   'PivotRI-2index': 0.003662,
#   'Trans-Cholesky': 0.0048833,
#   'Trans-TriInv': 0.0056188,
#   'Trans-Gemm': 0.11555,
#   'Trans-Copy': 0.06923,
#   'Trans': 0.19545,
#   'T2': 14.522,
#   'TotalT': 57.883},
#  ('1e-6', '1e-2', 200): {'NERI1': 21670,
#   'ERI1': 299.67,
#   'ERIvec': 21.743,
#   'ERIcopy': 0.015484,
#   'ERItrans': 0.017235,
#   'CDalgMM': 0.058602,
#   'CDalgMV': 0.048187,
#   'Shrink count': 20,
#   'Shrink': 0.71794,
#   'misc': 2.7085,
#   'T1': 25.309,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.3,
#   'PivotRI-3index': 14.56,
#   'PivotRI-2index': 0.00085394,
#   'Trans-Cholesky': 0.0083636,
#   'Trans-TriInv': 0.0071772,
#   'Trans-Gemm': 0.085044,
#   'Trans-Copy': 0.066202,
#   'Trans': 0.16695,
#   'T2': 14.728,
#   'TotalT': 40.037},
#  ('1e-6', '1e-2', 5000): {'NERI1': 34548,
#   'ERI1': 350.67,
#   'ERIvec': 35.013,
#   'ERIcopy': 0.045498,
#   'ERItrans': 0.015148,
#   'CDalgMM': 0.097295,
#   'CDalgMV': 0.087396,
#   'Shrink count': 3,
#   'Shrink': 0.32025,
#   'misc': 3.1227,
#   'T1': 38.701,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.3,
#   'PivotRI-3index': 14.399,
#   'PivotRI-2index': 0.0017064,
#   'Trans-Cholesky': 0.019962,
#   'Trans-TriInv': 0.0069779,
#   'Trans-Gemm': 0.09932,
#   'Trans-Copy': 0.069831,
#   'Trans': 0.19629,
#   'T2': 14.597,
#   'TotalT': 53.3},
#  ('1e-6', '1e-2', 100): {'NERI1': 19875,
#   'ERI1': 289.98,
#   'ERIvec': 21.919,
#   'ERIcopy': 0.049506,
#   'ERItrans': 0.014934,
#   'CDalgMM': 0.062883,
#   'CDalgMV': 0.055303,
#   'Shrink count': 31,
#   'Shrink': 1.0455,
#   'misc': 2.7688,
#   'T1': 25.916,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.78,
#   'PivotRI-3index': 14.541,
#   'PivotRI-2index': 0.0038708,
#   'Trans-Cholesky': 0.0059803,
#   'Trans-TriInv': 0.0055543,
#   'Trans-Gemm': 0.081046,
#   'Trans-Copy': 0.081125,
#   'Trans': 0.17388,
#   'T2': 14.719,
#   'TotalT': 40.638},
#  ('1e-6', '1e-2', 50): {'NERI1': 18113,
#   'ERI1': 278.96,
#   'ERIvec': 19.009,
#   'ERIcopy': 0.049473,
#   'ERItrans': 0.013756,
#   'CDalgMM': 0.092978,
#   'CDalgMV': 0.045945,
#   'Shrink count': 53,
#   'Shrink': 1.7491,
#   'misc': 2.6861,
#   'T1': 23.646,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.76,
#   'PivotRI-3index': 14.56,
#   'PivotRI-2index': 0.00085953,
#   'Trans-Cholesky': 0.0040586,
#   'Trans-TriInv': 0.0056876,
#   'Trans-Gemm': 0.080373,
#   'Trans-Copy': 0.066467,
#   'Trans': 0.15671,
#   'T2': 14.718,
#   'TotalT': 38.365},
#  ('1e-6', '1e-2', 20): {'NERI1': 17427,
#   'ERI1': 272.81,
#   'ERIvec': 16.146,
#   'ERIcopy': 0.010361,
#   'ERItrans': 0.016816,
#   'CDalgMM': 0.098103,
#   'CDalgMV': 0.050933,
#   'Shrink count': 110,
#   'Shrink': 3.6068,
#   'misc': 2.8647,
#   'T1': 22.794,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.44,
#   'PivotRI-3index': 14.744,
#   'PivotRI-2index': 0.008762,
#   'Trans-Cholesky': 0.0099082,
#   'Trans-TriInv': 0.0050018,
#   'Trans-Gemm': 0.076908,
#   'Trans-Copy': 0.066475,
#   'Trans': 0.15849,
#   'T2': 14.911,
#   'TotalT': 37.705},
#  ('1e-6', '1e-2', 1): {'NERI1': 17076,
#   'ERI1': 265.08,
#   'ERIvec': 15.881,
#   'ERIcopy': 0.04302,
#   'ERItrans': 0.022299,
#   'CDalgMM': 1.2824,
#   'CDalgMV': 0.035332,
#   'Shrink count': 1320,
#   'Shrink': 38.394,
#   'misc': 2.8474,
#   'T1': 58.505,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 270.03,
#   'PivotRI-3index': 14.298,
#   'PivotRI-2index': 0.0022408,
#   'Trans-Cholesky': 0.010278,
#   'Trans-TriInv': 0.0056229,
#   'Trans-Gemm': 0.078618,
#   'Trans-Copy': 0.068379,
#   'Trans': 0.16315,
#   'T2': 14.464,
#   'TotalT': 72.972},
#  ('1e-6', '1e-2', 20000): {'NERI1': 34788,
#   'ERI1': 352.19,
#   'ERIvec': 35.163,
#   'ERIcopy': 0.043814,
#   'ERItrans': 0.016047,
#   'CDalgMM': 0.12819,
#   'CDalgMV': 0.083794,
#   'Shrink count': 3,
#   'Shrink': 0.28464,
#   'misc': 2.7469,
#   'T1': 38.466,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.72,
#   'PivotRI-3index': 14.31,
#   'PivotRI-2index': 0.0014517,
#   'Trans-Cholesky': 0.021472,
#   'Trans-TriInv': 0.0051035,
#   'Trans-Gemm': 0.075523,
#   'Trans-Copy': 0.065889,
#   'Trans': 0.16819,
#   'T2': 14.48,
#   'TotalT': 52.949},
#  ('1e-6', '5e-3', 1000): {'NERI1': 25126,
#   'ERI1': 312.49,
#   'ERIvec': 23.439,
#   'ERIcopy': 0.03991,
#   'ERItrans': 0.074534,
#   'CDalgMM': 0.07405,
#   'CDalgMV': 0.088459,
#   'Shrink count': 7,
#   'Shrink': 0.35426,
#   'misc': 2.753,
#   'T1': 26.823,
#   'Aux dim': 1321,
#   'NERI2': 20271,
#   'ERI2': 269.51,
#   'PivotRI-3index': 14.538,
#   'PivotRI-2index': 0.013254,
#   'Trans-Cholesky': 0.011654,
#   'Trans-TriInv': 0.0052246,
#   'Trans-Gemm': 0.080842,
#   'Trans-Copy': 0.075108,
#   'Trans': 0.173,
#   'T2': 14.724,
#   'TotalT': 41.549},
#  ('1e-6', '5e-3', 500): {'NERI1': 23263,
#   'ERI1': 306.35,
#   'ERIvec': 23.25,
#   'ERIcopy': 0.017186,
# ...
#   'Trans-Copy': 0.040373,
#   'Trans': 0.098039,
#   'T2': 10.149,
#   'TotalT': 48.607},
#  ('1e-4', '5e-3', 1000): {'NERI1': 15453,
#   'ERI1': 259.37,
#   'ERIvec': 21.733,
#   'ERIcopy': 0.019902,
#   'ERItrans': 0.011653,
#   'CDalgMM': 0.018175,
#   'CDalgMV': 0.034084,
#   'Shrink count': 5,
#   'Shrink': 0.17497,
#   'misc': 2.7161,
#   'T1': 24.707,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 212.05,
#   'PivotRI-3index': 10.296,
#   'PivotRI-2index': 0.00030429,
#   'Trans-Cholesky': 0.0027231,
#   'Trans-TriInv': 0.0026133,
#   'Trans-Gemm': 0.047426,
#   'Trans-Copy': 0.039645,
#   'Trans': 0.092547,
#   'T2': 10.389,
#   'TotalT': 35.1},
#  ('1e-4', '5e-3', 500): {'NERI1': 14213,
#   'ERI1': 239.78,
#   'ERIvec': 20.149,
#   'ERIcopy': 0.017851,
#   'ERItrans': 0.0081235,
#   'CDalgMM': 0.025856,
#   'CDalgMV': 0.032206,
#   'Shrink count': 7,
#   'Shrink': 0.22078,
#   'misc': 2.8593,
#   'T1': 23.313,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.54,
#   'PivotRI-3index': 10.109,
#   'PivotRI-2index': 0.0003929,
#   'Trans-Cholesky': 0.00192,
#   'Trans-TriInv': 0.0027141,
#   'Trans-Gemm': 0.047022,
#   'Trans-Copy': 0.039698,
#   'Trans': 0.091481,
#   'T2': 10.201,
#   'TotalT': 33.517},
#  ('1e-4', '5e-3', 2000): {'NERI1': 25161,
#   'ERI1': 308.96,
#   'ERIvec': 25.514,
#   'ERIcopy': 0.018984,
#   'ERItrans': 0.011518,
#   'CDalgMM': 0.022804,
#   'CDalgMV': 0.040972,
#   'Shrink count': 3,
#   'Shrink': 0.13101,
#   'misc': 2.6914,
#   'T1': 28.431,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 212.06,
#   'PivotRI-3index': 10.184,
#   'PivotRI-2index': 0.00044618,
#   'Trans-Cholesky': 0.010913,
#   'Trans-TriInv': 0.0037635,
#   'Trans-Gemm': 0.055922,
#   'Trans-Copy': 0.040221,
#   'Trans': 0.11094,
#   'T2': 10.295,
#   'TotalT': 38.727},
#  ('1e-4', '5e-3', 200): {'NERI1': 12763,
#   'ERI1': 230.27,
#   'ERIvec': 19.738,
#   'ERIcopy': 0.012015,
#   'ERItrans': 0.0043465,
#   'CDalgMM': 0.026476,
#   'CDalgMV': 0.042021,
#   'Shrink count': 12,
#   'Shrink': 0.32447,
#   'misc': 2.7187,
#   'T1': 22.866,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.72,
#   'PivotRI-3index': 9.9406,
#   'PivotRI-2index': 0.00032721,
#   'Trans-Cholesky': 0.0033718,
#   'Trans-TriInv': 0.002503,
#   'Trans-Gemm': 0.046945,
#   'Trans-Copy': 0.039,
#   'Trans': 0.091943,
#   'T2': 10.033,
#   'TotalT': 32.902},
#  ('1e-4', '5e-3', 5000): {'NERI1': 29670,
#   'ERI1': 318.14,
#   'ERIvec': 27.908,
#   'ERIcopy': 0.025451,
#   'ERItrans': 0.012218,
#   'CDalgMM': 0.017793,
#   'CDalgMV': 0.058154,
#   'Shrink count': 2,
#   'Shrink': 0.1231,
#   'misc': 2.7119,
#   'T1': 30.857,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.64,
#   'PivotRI-3index': 10.009,
#   'PivotRI-2index': 0.00031511,
#   'Trans-Cholesky': 0.0017704,
#   'Trans-TriInv': 0.0032439,
#   'Trans-Gemm': 0.041563,
#   'Trans-Copy': 0.041475,
#   'Trans': 0.088166,
#   'T2': 10.098,
#   'TotalT': 40.957},
#  ('1e-4', '5e-3', 100): {'NERI1': 12165,
#   'ERI1': 223.04,
#   'ERIvec': 18.711,
#   'ERIcopy': 0.013995,
#   'ERItrans': 0.0065808,
#   'CDalgMM': 0.0462,
#   'CDalgMV': 0.027281,
#   'Shrink count': 19,
#   'Shrink': 0.41874,
#   'misc': 2.6839,
#   'T1': 21.907,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 218.89,
#   'PivotRI-3index': 10.277,
#   'PivotRI-2index': 0.0039335,
#   'Trans-Cholesky': 0.0035703,
#   'Trans-TriInv': 0.0026239,
#   'Trans-Gemm': 0.071748,
#   'Trans-Copy': 0.035386,
#   'Trans': 0.11344,
#   'T2': 10.394,
#   'TotalT': 32.303},
#  ('1e-4', '5e-3', 50): {'NERI1': 12020,
#   'ERI1': 214.93,
#   'ERIvec': 16.257,
#   'ERIcopy': 0.013521,
#   'ERItrans': 0.006914,
#   'CDalgMM': 0.052263,
#   'CDalgMV': 0.024424,
#   'Shrink count': 34,
#   'Shrink': 0.73322,
#   'misc': 2.6841,
#   'T1': 19.772,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.66,
#   'PivotRI-3index': 9.9477,
#   'PivotRI-2index': 0.012291,
#   'Trans-Cholesky': 0.0021791,
#   'Trans-TriInv': 0.0026451,
#   'Trans-Gemm': 0.040233,
#   'Trans-Copy': 0.040904,
#   'Trans': 0.086104,
#   'T2': 10.046,
#   'TotalT': 29.821},
#  ('1e-4', '5e-3', 20): {'NERI1': 11557,
#   'ERI1': 210.33,
#   'ERIvec': 13.918,
#   'ERIcopy': 0.0057318,
#   'ERItrans': 0.0088144,
#   'CDalgMM': 0.03236,
#   'CDalgMV': 0.025137,
#   'Shrink count': 71,
#   'Shrink': 1.5723,
#   'misc': 2.8326,
#   'T1': 18.395,
#   'Aux dim': 839,
#   'NERI2': 14136,
#   'ERI2': 212.34,
#   'PivotRI-3index': 10.015,
#   'PivotRI-2index': 0.0011361,
#   'Trans-Cholesky': 0.0092714,
#   'Trans-TriInv': 0.0038227,
#   'Trans-Gemm': 0.070201,
#   'Trans-Copy': 0.042822,
#   'Trans': 0.12628,
#   'T2': 10.143,
#   'TotalT': 28.54},
#  ('1e-4', '5e-3', 1): {'NERI1': 11307,
#   'ERI1': 200.07,
#   'ERIvec': 13.23,
#   'ERIcopy': 0.019555,
#   'ERItrans': 0.012117,
#   'CDalgMM': 0.39492,
#   'CDalgMV': 0.013552,
#   'Shrink count': 838,
#   'Shrink': 16.003,
#   'misc': 2.8657,
#   'T1': 32.538,
#   'Aux dim': 839,
#   'NERI2': 14136,
#   'ERI2': 211.98,
#   'PivotRI-3index': 10.16,
#   'PivotRI-2index': 0.0011208,
#   'Trans-Cholesky': 0.015971,
#   'Trans-TriInv': 0.0026564,
#   'Trans-Gemm': 0.04878,
#   'Trans-Copy': 0.052523,
#   'Trans': 0.12012,
#   'T2': 10.281,
#   'TotalT': 42.822},
#  ('1e-4', '5e-3', 20000): {'NERI1': 29670,
#   'ERI1': 323.05,
#   'ERIvec': 28.034,
#   'ERIcopy': 0.037717,
#   'ERItrans': 0.01181,
#   'CDalgMM': 0.025293,
#   'CDalgMV': 0.055745,
#   'Shrink count': 2,
#   'Shrink': 0.1159,
#   'misc': 2.8113,
#   'T1': 31.091,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 212.13,
#   'PivotRI-3index': 9.9526,
#   'PivotRI-2index': 0.012953,
#   'Trans-Cholesky': 0.0034581,
#   'Trans-TriInv': 0.0023982,
#   'Trans-Gemm': 0.039076,
#   'Trans-Copy': 0.039102,
#   'Trans': 0.084162,
#   'T2': 10.05,
#   'TotalT': 41.143},
#  ('1e-4', '1e-3', 1000): {'NERI1': 18821,
#   'ERI1': 273.88,
#   'ERIvec': 22.062,
#   'ERIcopy': 0.043295,
#   'ERItrans': 0.0055665,
#   'CDalgMM': 0.019375,
#   'CDalgMV': 0.03013,
#   'Shrink count': 4,
#   'Shrink': 0.10901,
#   'misc': 2.7178,
#   'T1': 24.987,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.7,
#   'PivotRI-3index': 10.08,
#   'PivotRI-2index': 0.0010154,
#   'Trans-Cholesky': 0.003776,
#   'Trans-TriInv': 0.0026684,
#   'Trans-Gemm': 0.044635,
#   'Trans-Copy': 0.042068,
#   'Trans': 0.093286,
#   'T2': 10.175,
#   'TotalT': 35.165},
#  ('1e-4', '1e-3', 500): {'NERI1': 13715,
#   'ERI1': 243.91,
#   'ERIvec': 20.215,
#   'ERIcopy': 0.0093288,
#   'ERItrans': 0.0026886,
#   'CDalgMM': 0.017556,
#   'CDalgMV': 0.033514,
#   'Shrink count': 6,
#   'Shrink': 0.13166,
#   'misc': 2.7334,
#   'T1': 23.143,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.84,
#   'PivotRI-3index': 9.9546,
#   'PivotRI-2index': 0.0077692,
#   'Trans-Cholesky': 0.0072877,
#   'Trans-TriInv': 0.0026775,
#   'Trans-Gemm': 0.074727,
#   'Trans-Copy': 0.056112,
#   'Trans': 0.14099,
#   'T2': 10.104,
#   'TotalT': 33.247},
#  ('1e-4', '1e-3', 2000): {'NERI1': 24611,
#   'ERI1': 306.38,
#   'ERIvec': 24.559,
#   'ERIcopy': 0.017209,
#   'ERItrans': 0.011377,
#   'CDalgMM': 0.025826,
#   'CDalgMV': 0.03659,
#   'Shrink count': 3,
#   'Shrink': 0.10056,
#   'misc': 2.9732,
#   'T1': 27.723,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 212.11,
#   'PivotRI-3index': 9.9686,
#   'PivotRI-2index': 0.00034637,
#   'Trans-Cholesky': 0.0041288,
#   'Trans-TriInv': 0.0025652,
#   'Trans-Gemm': 0.042361,
#   'Trans-Copy': 0.039683,
#   'Trans': 0.088888,
#   'T2': 10.058,
#   'TotalT': 37.782},
#  ('1e-4', '1e-3', 200): {'NERI1': 12763,
#   'ERI1': 230.74,
#   'ERIvec': 19.733,
#   'ERIcopy': 0.021311,
#   'ERItrans': 0.067231,
#   'CDalgMM': 0.031988,
#   'CDalgMV': 0.073266,
#   'Shrink count': 12,
#   'Shrink': 0.2875,
#   'misc': 2.7625,
#   'T1': 22.977,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.75,
#   'PivotRI-3index': 10.226,
#   'PivotRI-2index': 0.00029227,
#   'Trans-Cholesky': 0.0031181,
#   'Trans-TriInv': 0.0026528,
#   'Trans-Gemm': 0.046847,
#   'Trans-Copy': 0.040227,
#   'Trans': 0.092967,
#   'T2': 10.32,
#   'TotalT': 33.298},
#  ('1e-4', '1e-3', 5000): {'NERI1': 29001,
#   'ERI1': 318.09,
#   'ERIvec': 26.088,
#   'ERIcopy': 0.025963,
#   'ERItrans': 0.0112,
#   'CDalgMM': 0.020689,
#   'CDalgMV': 0.047718,
#   'Shrink count': 2,
#   'Shrink': 0.078953,
#   'misc': 2.6849,
#   'T1': 28.958,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 212.19,
#   'PivotRI-3index': 9.949,
#   'PivotRI-2index': 0.00039053,
#   'Trans-Cholesky': 0.0028424,
#   'Trans-TriInv': 0.0034011,
#   'Trans-Gemm': 0.046179,
#   'Trans-Copy': 0.040031,
#   'Trans': 0.092611,
#   'T2': 10.042,
#   'TotalT': 39.001},
#  ('1e-4', '1e-3', 100): {'NERI1': 12165,
#   'ERI1': 220.96,
#   'ERIvec': 18.4,
#   'ERIcopy': 0.0073591,
#   'ERItrans': 0.0057009,
#   'CDalgMM': 0.037161,
#   'CDalgMV': 0.023685,
#   'Shrink count': 19,
#   'Shrink': 0.4489,
#   'misc': 2.7147,
#   'T1': 21.638,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.87,
#   'PivotRI-3index': 9.9726,
#   'PivotRI-2index': 0.00047726,
#   'Trans-Cholesky': 0.0048992,
#   'Trans-TriInv': 0.0025483,
#   'Trans-Gemm': 0.060951,
#   'Trans-Copy': 0.037617,
#   'Trans': 0.10617,
#   'T2': 10.079,
#   'TotalT': 31.72},
#  ('1e-4', '1e-3', 50): {'NERI1': 12020,
#   'ERI1': 214.37,
#   'ERIvec': 15.945,
#   'ERIcopy': 0.015577,
#   'ERItrans': 0.0071402,
#   'CDalgMM': 0.050624,
#   'CDalgMV': 0.024077,
#   'Shrink count': 34,
#   'Shrink': 0.76179,
#   'misc': 2.6477,
#   'T1': 19.452,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.73,
#   'PivotRI-3index': 10.123,
#   'PivotRI-2index': 0.012932,
#   'Trans-Cholesky': 0.02888,
#   'Trans-TriInv': 0.0047844,
#   'Trans-Gemm': 0.043465,
#   'Trans-Copy': 0.036117,
#   'Trans': 0.11337,
#   'T2': 10.249,
#   'TotalT': 29.702},
#  ('1e-4', '1e-3', 20): {'NERI1': 11557,
#   'ERI1': 209.92,
#   'ERIvec': 14.054,
#   'ERIcopy': 0.0063671,
#   'ERItrans': 0.0087891,
#   'CDalgMM': 0.03428,
#   'CDalgMV': 0.023499,
#   'Shrink count': 71,
#   'Shrink': 1.5456,
#   'misc': 2.6574,
#   'T1': 18.33,
#   'Aux dim': 839,
#   'NERI2': 14136,
#   'ERI2': 212.05,
#   'PivotRI-3index': 9.9417,
#   'PivotRI-2index': 0.00037031,
#   'Trans-Cholesky': 0.019793,
#   'Trans-TriInv': 0.003181,
#   'Trans-Gemm': 0.047147,
#   'Trans-Copy': 0.042331,
#   'Trans': 0.11262,
#   'T2': 10.055,
#   'TotalT': 28.386},
#  ('1e-4', '1e-3', 1): {'NERI1': 11307,
#   'ERI1': 200.29,
#   'ERIvec': 13.445,
#   'ERIcopy': 0.016755,
#   'ERItrans': 0.020794,
#   'CDalgMM': 0.44772,
#   'CDalgMV': 0.014859,
#   'Shrink count': 838,
#   'Shrink': 15.529,
#   'misc': 2.7672,
#   'T1': 32.242,
#   'Aux dim': 839,
#   'NERI2': 14136,
#   'ERI2': 211.89,
#   'PivotRI-3index': 9.9382,
#   'PivotRI-2index': 0.00054529,
#   'Trans-Cholesky': 0.018623,
#   'Trans-TriInv': 0.0036544,
#   'Trans-Gemm': 0.041206,
#   'Trans-Copy': 0.041174,
#   'Trans': 0.10481,
#   'T2': 10.044,
#   'TotalT': 42.287},
#  ('1e-4', '1e-3', 20000): {'NERI1': 31347,
#   'ERI1': 319.09,
#   'ERIvec': 25.015,
#   'ERIcopy': 0.034121,
#   'ERItrans': 0.012213,
#   'CDalgMM': 0.018695,
#   'CDalgMV': 0.057822,
#   'Shrink count': 1,
#   'Shrink': 0.072804,
#   'misc': 3.0215,
#   'T1': 28.232,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.8,
#   'PivotRI-3index': 9.9624,
#   'PivotRI-2index': 0.002446,
#   'Trans-Cholesky': 0.013776,
#   'Trans-TriInv': 0.0030757,
#   'Trans-Gemm': 0.041619,
#   'Trans-Copy': 0.039103,
#   'Trans': 0.097788,
#   'T2': 10.063,
#   'TotalT': 38.299},
#  ('1e-4', '5e-4', 1000): {'NERI1': 20224,
#   'ERI1': 276.4,
#   'ERIvec': 22.192,
#   'ERIcopy': 0.012606,
#   'ERItrans': 0.0031949,
#   'CDalgMM': 0.018937,
#   'CDalgMV': 0.030501,
#   'Shrink count': 4,
#   'Shrink': 0.089779,
#   'misc': 2.7095,
#   'T1': 25.056,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.97,
#   'PivotRI-3index': 10.022,
#   'PivotRI-2index': 0.00044816,
#   'Trans-Cholesky': 0.0093899,
#   'Trans-TriInv': 0.0038265,
#   'Trans-Gemm': 0.068067,
#   'Trans-Copy': 0.069732,
#   'Trans': 0.1512,
#   'T2': 10.174,
#   'TotalT': 35.231},
#  ('1e-4', '5e-4', 500): {'NERI1': 13715,
#   'ERI1': 242.75,
#   'ERIvec': 20.447,
#   'ERIcopy': 0.0082481,
#   'ERItrans': 0.0025209,
#   'CDalgMM': 0.01711,
#   'CDalgMV': 0.028278,
#   'Shrink count': 6,
#   'Shrink': 0.1443,
#   'misc': 2.7203,
#   'T1': 23.367,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.59,
#   'PivotRI-3index': 9.9433,
#   'PivotRI-2index': 0.0076203,
#   'Trans-Cholesky': 0.003221,
#   'Trans-TriInv': 0.0024863,
#   'Trans-Gemm': 0.040317,
#   'Trans-Copy': 0.039653,
#   'Trans': 0.085805,
#   'T2': 10.037,
#   'TotalT': 33.407},
#  ('1e-4', '5e-4', 2000): {'NERI1': 23235,
#   'ERI1': 303.42,
#   'ERIvec': 24.47,
#   'ERIcopy': 0.013147,
#   'ERItrans': 0.0063994,
#   'CDalgMM': 0.025171,
#   'CDalgMV': 0.041956,
#   'Shrink count': 3,
#   'Shrink': 0.10271,
#   'misc': 2.9238,
#   'T1': 27.583,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.86,
#   'PivotRI-3index': 9.9598,
#   'PivotRI-2index': 0.0084807,
#   'Trans-Cholesky': 0.0025689,
#   'Trans-TriInv': 0.0031516,
#   'Trans-Gemm': 0.042382,
#   'Trans-Copy': 0.041855,
#   'Trans': 0.090087,
#   'T2': 10.059,
#   'TotalT': 37.645},
#  ('1e-4', '5e-4', 200): {'NERI1': 12763,
#   'ERI1': 232.33,
#   'ERIvec': 19.976,
#   'ERIcopy': 0.017268,
#   'ERItrans': 0.008175,
#   'CDalgMM': 0.019604,
#   'CDalgMV': 0.023948,
#   'Shrink count': 12,
#   'Shrink': 0.27085,
#   'misc': 2.6626,
#   'T1': 22.979,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.63,
#   'PivotRI-3index': 10.187,
#   'PivotRI-2index': 0.00050707,
#   'Trans-Cholesky': 0.0082728,
#   'Trans-TriInv': 0.003248,
#   'Trans-Gemm': 0.070898,
#   'Trans-Copy': 0.052743,
#   'Trans': 0.13533,
#   'T2': 10.323,
#   'TotalT': 33.304},
#  ('1e-4', '5e-4', 5000): {'NERI1': 26787,
#   'ERI1': 312.64,
#   'ERIvec': 25.489,
#   'ERIcopy': 0.050214,
#   'ERItrans': 0.0091069,
#   'CDalgMM': 0.035708,
#   'CDalgMV': 0.055606,
#   'Shrink count': 2,
#   'Shrink': 0.067814,
#   'misc': 3.0805,
#   'T1': 28.788,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.74,
#   'PivotRI-3index': 9.9484,
#   'PivotRI-2index': 0.00031849,
#   'Trans-Cholesky': 0.011585,
#   'Trans-TriInv': 0.0024532,
#   'Trans-Gemm': 0.040715,
#   'Trans-Copy': 0.040503,
#   'Trans': 0.095454,
#   'T2': 10.044,
#   'TotalT': 38.836},
#  ('1e-4', '5e-4', 100): {'NERI1': 12165,
#   'ERI1': 220.51,
#   'ERIvec': 18.339,
#   'ERIcopy': 0.0059954,
#   'ERItrans': 0.011691,
#   'CDalgMM': 0.037069,
#   'CDalgMV': 0.023821,
#   'Shrink count': 19,
#   'Shrink': 0.45335,
#   'misc': 2.6965,
#   'T1': 21.567,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 212.32,
#   'PivotRI-3index': 10.179,
#   'PivotRI-2index': 0.0007224,
#   'Trans-Cholesky': 0.0024515,
#   'Trans-TriInv': 0.0025519,
#   'Trans-Gemm': 0.067092,
#   'Trans-Copy': 0.036934,
#   'Trans': 0.10918,
#   'T2': 10.289,
#   'TotalT': 31.859},
#  ('1e-4', '5e-4', 50): {'NERI1': 12020,
#   'ERI1': 214.97,
#   'ERIvec': 15.976,
#   'ERIcopy': 0.014013,
#   'ERItrans': 0.010795,
#   'CDalgMM': 0.067355,
#   'CDalgMV': 0.02436,
#   'Shrink count': 34,
#   'Shrink': 0.7873,
#   'misc': 2.8532,
#   'T1': 19.733,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 211.81,
#   'PivotRI-3index': 9.9517,
#   'PivotRI-2index': 0.00043748,
#   'Trans-Cholesky': 0.0036554,
#   'Trans-TriInv': 0.0032041,
#   'Trans-Gemm': 0.04867,
#   'Trans-Copy': 0.049464,
#   'Trans': 0.10514,
#   'T2': 10.057,
#   'TotalT': 29.793},
#  ('1e-4', '5e-4', 20): {'NERI1': 11557,
#   'ERI1': 209.61,
#   'ERIvec': 13.76,
#   'ERIcopy': 0.005306,
#   'ERItrans': 0.0085738,
#   'CDalgMM': 0.029756,
#   'CDalgMV': 0.0241,
#   'Shrink count': 71,
#   'Shrink': 1.4952,
#   'misc': 2.7998,
#   'T1': 18.123,
#   'Aux dim': 839,
#   'NERI2': 14136,
#   'ERI2': 211.66,
#   'PivotRI-3index': 9.9435,
#   'PivotRI-2index': 0.0010478,
#   'Trans-Cholesky': 0.01501,
#   'Trans-TriInv': 0.0026189,
#   'Trans-Gemm': 0.040904,
#   'Trans-Copy': 0.044684,
#   'Trans': 0.10338,
#   'T2': 10.048,
#   'TotalT': 28.174},
#  ('1e-4', '5e-4', 1): {'NERI1': 11307,
#   'ERI1': 200.67,
#   'ERIvec': 13.49,
#   'ERIcopy': 0.018916,
#   'ERItrans': 0.01551,
#   'CDalgMM': 0.41805,
#   'CDalgMV': 0.013374,
#   'Shrink count': 838,
#   'Shrink': 16.113,
#   'misc': 2.916,
#   'T1': 32.985,
#   'Aux dim': 839,
#   'NERI2': 14136,
#   'ERI2': 211.55,
#   'PivotRI-3index': 9.9307,
#   'PivotRI-2index': 0.00044067,
#   'Trans-Cholesky': 0.011681,
#   'Trans-TriInv': 0.0032414,
#   'Trans-Gemm': 0.054549,
#   'Trans-Copy': 0.053146,
#   'Trans': 0.12282,
#   'T2': 10.054,
#   'TotalT': 43.042},
#  ('1e-4', '5e-4', 20000): {'NERI1': 27528,
#   'ERI1': 310.91,
#   'ERIvec': 26.216,
#   'ERIcopy': 0.02579,
#   'ERItrans': 0.0097827,
#   'CDalgMM': 0.022694,
#   'CDalgMV': 0.050129,
#   'Shrink count': 1,
#   'Shrink': 0.068201,
#   'misc': 2.757,
#   'T1': 29.149,
#   'Aux dim': 838,
#   'NERI2': 14136,
#   'ERI2': 213.4,
#   'PivotRI-3index': 10.255,
#   'PivotRI-2index': 0.0022942,
#   'Trans-Cholesky': 0.016036,
#   'Trans-TriInv': 0.0024638,
#   'Trans-Gemm': 0.041944,
#   'Trans-Copy': 0.038752,
#   'Trans': 0.099355,
#   'T2': 10.356,
#   'TotalT': 39.51}}

# %%
# Plot the effect of m_sigma
fig, ax = plt.subplots(3,6,sharex=True, sharey=True,figsize=(12,6))
row = -1
column = -1
print('----------------------------------------------------------------------------------------------------')
print('----------------------------------------------LIBINTG-----------------------------------------------')
print('----------------------------------------------------------------------------------------------------')
for tau in taus:
    column = -1
    row += 1
#     print('\n')
#     print('\n')
#     print('----------------------------------------------',gen,tau, '----------------------------------------------')
    
    for sigma in sigmas:
        column += 1
        T1 = []
#         print('\n')
#         print('----------',gen,tau,sigma,  '----------')
        for maxqual in maxquals:
            T1.append(times[(tau,sigma,maxqual)]['T1'])
        
        ax[row,column].scatter(maxquals,T1, s=5)
        ax[row,column].set_xscale("log")
        subplot_title = "$\\tau=$" + str(tau) + ",$\sigma=$" + str(sigma)
        ax[row,column].set_title(subplot_title)
        #ax[row,column].set_xticks(maxquals_small)
        for i, txt in enumerate(maxquals):
            ax[row,column].annotate(txt, (maxquals[i], T1[i]))

plt.xlabel("$m_{\sigma}$")
plt.ylabel("Time (s)")
plt.tight_layout()
plt.savefig('plot_msigma.pdf')
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------LIBINTG-----------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
# Plot the effect of sigma, libcintG
fig, ax = plt.subplots(3,10,sharex=True, sharey=True,figsize=(20,6))
row = -1
column = -1
print('----------------------------------------------------------------------------------------------------')
print('----------------------------------------------LIBINTG-----------------------------------------------')
print('----------------------------------------------------------------------------------------------------')
for tau in taus:
    column = -1
    row += 1
#     print('\n')
#     print('\n')
#     print('----------------------------------------------',gen,tau, '----------------------------------------------')
    
    for maxqual in maxquals_sorted:
        column += 1
        T1 = []
#         print('\n')
#         print('----------',gen,tau,sigma,  '----------')
        for sigma in sigmas:
            T1.append(times[(tau,sigma,maxqual)]['T1'])
        
        ax[row,column].scatter(sigmas,T1, s=5)
        ax[row,column].set_xscale("log")
        subplot_title = "$\\tau=$" + str(tau) + ",$msigma=$" + str(maxqual)
        ax[row,column].set_title(subplot_title)
        #ax[row,column].set_xticks(maxquals_small)
        for i, txt in enumerate(sigmas):
            ax[row,column].annotate(txt, (sigmas[i], T1[i]))

plt.xlabel("$\sigma$")
plt.ylabel("Time (s)")
plt.tight_layout()
plt.savefig('plot_sigma.pdf')
plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------LIBINTG-----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# <ipython-input-21-1c3ff8d47877>:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
