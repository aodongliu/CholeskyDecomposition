# %%
import os.path
import math

# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager
from matplotlib.ticker import NullLocator
import numpy as np
from matplotlib.cm import ScalarMappable

# %% [markdown]
# ##  This notebook attempts to analyze the effects of sigma and msigma for the DynamicERI cholesky decomposition algorithm for H1000 system

# %% [markdown]
# #### Define useful functions:

# %%
def set_shared_ylabel(a, ylabel, labelsize, labelpad = 0.01):
    """Set a y label shared by multiple axes
    Parameters
    ----------
    a: list of axes
    ylabel: string
    labelsize: integer
    labelpad: float
        Sets the padding between ticklabels and axis label"""

    f = a[0].get_figure()
    f.canvas.draw() #sets f.canvas.renderer needed below

    # get the center position for all plots
    top = a[0].get_position().y1
    bottom = a[-1].get_position().y0

    # get the coordinates of the left side of the tick labels 
    x0 = 1
    for at in a:
        at.set_ylabel('') # just to make sure we don't and up with multiple labels
        bboxes, _ = at.yaxis.get_ticklabel_extents(f.canvas.renderer)
        bboxes = bboxes.inverse_transformed(f.transFigure)
        xt = bboxes.x0
        if xt < x0:
            x0 = xt
    tick_label_left = x0

    # set position of label
    a[-1].set_ylabel(ylabel,fontsize=labelsize)
    a[-1].yaxis.set_label_coords(tick_label_left - labelpad,(bottom + top)/2, transform=f.transFigure)

# %%
# This function parses the output and returns two directionaries:

# dynamicERIProgress is a dictionary of lists that store the progress of each variable during CD
# dynamicERITotal is a dictionary of ints/floats that hold cumulataive data
def parseOutput(fname):

    if not os.path.exists(fname):
        return None
    f = open(fname)

    # dynamicERIProgress is a dictionary object that holds the step-by-step data obtained during the CD progress
    dynamicERIProgress = {}
    # dynamicERITotal is a dictionary object that holds cumulataive data
    dynamicERITotal = {}


    # Initialize the following keys for dynamicERIProgress to hold lists:

    # Pivot candidates. This corresponds to P in the paper
    dynamicERIProgress['D_size']= []

    # The current batch selected based on sigma and msigma. This corresponds to Q in the paper
    dynamicERIProgress['lenQ']= []

    # The number of computed ERI vectors (of length D) stored in memory. This corresponds to Epsilon in the paper
    dynamicERIProgress['ERI_vec']= []

    # The time used for shrinking of the current batch. This corresponds to line 39
    dynamicERIProgress['shrink_time']= []

    # Time used to do transpose for the current batch
    dynamicERIProgress['ERI_trans']= []

    # The number of ERIs calculated for current batch. This corresponds to line 20
    dynamicERIProgress['ERI_count']= []

    # Time used to calculate ERI for current batch, all threads added together. This corresponds to line 20
    dynamicERIProgress['ERI_duration_all']= []

    # Time used to calculate ERI for current batch, wall clock. This corresponds to line 20
    dynamicERIProgress['RI_duration_wall']= []

    # Time used to copy for the current batch. This corresponds to line 22
    dynamicERIProgress['ERI_copy']= []

    # Time used to do CD for the current batch. This corresponds to line 22
    dynamicERIProgress['CDalgMM']= []

    # Time used to do CD for the current batch in the innerloop. This corresponds to line 30
    dynamicERIProgress['innerloop_CDalgMM']= []

    # Time used for the current batch in the innerloop. This corresponds to line 27-33
    dynamicERIProgress['innerloop_time']= []




    for line in f:

        # Add cumulative data key-value pairs into the dynamicERITotal dictionary 
        if 'Cholesky-RI-Pivots-ERI count' in line:
            dynamicERITotal['N1ERI'] = int(line.split('= ')[-1])

        if 'Cholesky-RI-Pivots-ERI duration' in line:
            dynamicERITotal['T1ERI_AllThreads'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-ERIvec duration     =' in line:
            dynamicERITotal['T1ERI_WC'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-ERIcopy duration    =' in line:
            dynamicERITotal['ERIcopy'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-ERItrans duration   =' in line:
            dynamicERITotal['ERItrans'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-CDalgMM duration    =' in line:
            dynamicERITotal['CDalgMM'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-CDalgMV duration    =' in line:
            dynamicERITotal['CDalgMV'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-Shrink count        =' in line:
            dynamicERITotal['NShrink'] = int(line.split('= ')[-1])

        if 'Cholesky-RI-Shrink duration     =' in line:
            dynamicERITotal['TShrink'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-misc duration       =' in line:
            dynamicERITotal['misc'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-Dynamic-ERI-Pivots duration =' in line:
            dynamicERITotal['T1'] = float(line.split('= ')[-1].split()[0])

        if 'Cholesky-RI-auxiliary dimension =' in line:
            dynamicERITotal['NPivots'] = int(line.split('= ')[-1])



        # Append values of each step into corresponding list in the dynamicERIProgress dictionary
        if 'D size =' in line:
            dynamicERIProgress['D_size'].append(float(line.split('= ')[-1]))

        if 'lenQ:' in line:
            dynamicERIProgress['lenQ'].append(int(line.split(':')[-1]))

        if 'ERI size =' in line:
            dynamicERIProgress['ERI_vec'].append(int(line.split('= ')[-1]))

        if 'Current Shrink =' in line:
            dynamicERIProgress['shrink_time'].append(float(line.split('= ')[-1].split()[0]))

        if 'Current ERItrans =' in line:
            dynamicERIProgress['ERI_trans'].append(float(line.split('= ')[-1].split()[0]))

        if 'Current ERI count    =' in line:
            dynamicERIProgress['ERI_count'].append(int(line.split('= ')[-1]))

        if 'Current ERI duration =' in line:
            dynamicERIProgress['ERI_duration_all'].append(float(line.split('= ')[-1].split()[0]))

        if 'Current ERIvec =' in line:
            dynamicERIProgress['RI_duration_wall'].append(float(line.split('= ')[-1].split()[0]))

        if 'Current ERIcopy =' in line:
            dynamicERIProgress['ERI_copy'].append(float(line.split('= ')[-1].split()[0]))

        if 'Current CDalgMM =' in line:
            dynamicERIProgress['CDalgMM'].append(float(line.split('= ')[-1].split()[0]))

        if 'InnerLoop CDalgMV  =' in line:
            dynamicERIProgress['innerloop_CDalgMM'].append(float(line.split('= ')[-1].split()[0]))

        if 'InnerLoop duration =' in line:
            dynamicERIProgress['innerloop_time'].append(float(line.split('= ')[-1].split()[0]))


    f.close()
    return dynamicERIProgress, dynamicERITotal

# %% [markdown]
# ##### Test if the parseOutput function works

# %%
# Test if the parseOutput function works 
progress,total=parseOutput('/Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/H1000_sto3g_libints_t1e-6_s1e-1_m1000.out')
progress.keys()
# Out:
# dict_keys(['D_size', 'lenQ', 'ERI_vec', 'shrink_time', 'ERI_trans', 'ERI_count', 'ERI_duration_all', 'RI_duration_wall', 'ERI_copy', 'CDalgMM', 'innerloop_CDalgMM', 'innerloop_time'])

# %%
for key in progress.keys():
    print(key, len(progress[key]), type(progress[key][0]))
# Out:
# D_size 31 <class 'float'>
# lenQ 31 <class 'int'>
# ERI_vec 31 <class 'int'>
# shrink_time 30 <class 'float'>
# ERI_trans 30 <class 'float'>
# ERI_count 31 <class 'int'>
# ERI_duration_all 31 <class 'float'>
# RI_duration_wall 31 <class 'float'>
# ERI_copy 31 <class 'float'>
# CDalgMM 31 <class 'float'>
# innerloop_CDalgMM 31 <class 'float'>
# innerloop_time 31 <class 'float'>

# %%
total
# Out:
# {'N1ERI': 267100523,
#  'T1ERI_AllThreads': 940.69,
#  'T1ERI_WC': 35.424,
#  'ERIcopy': 0.26089,
#  'ERItrans': 0.01317,
#  'CDalgMM': 3.7308,
#  'CDalgMV': 8.5117,
#  'NShrink': 30,
#  'TShrink': 2.753,
#  'misc': 2.2361,
#  'T1': 52.93,
#  'NPivots': 9168}

# %%
x = np.arange(1,total['NShrink']+1,1)
x1 = np.arange(1,total['NShrink']+2,1)

plt.plot(x1,progress['ERI_vec'])
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### 1. Libint Integral Engine, segmented contration

# %%
# Construct the name of the output files 
root = '/Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/'
system = 'H1000'
basis = 'sto3g'
integral_engine = 'libint'
contraction_type = 's'
taus = ['1e-8', '1e-6', '1e-4'] 
sigmas = ['1','5e-1','1e-1','5e-2','1e-2','5e-3','1e-3','5e-4','1e-4','5e-5','1e-5']
maxquals = [20000,5000,2000,1500,1250,1000,750,500,250,100,50,20,1]

H1000_Total = {}
H1000_Progress = {}

for tau in taus:
    for sigma in sigmas:
        for maxqual in maxquals:

            fname = root + system
            
            fname += '_%s_%s%s' % (basis,integral_engine,contraction_type)

            fname += '_t%s_s%s_m%d' % (tau,sigma,maxqual)

            fname += '.out'
            
            #print(fname)

            H1000_Progress[(tau,sigma,maxqual)], H1000_Total[(tau,sigma,maxqual)] = parseOutput(fname)

# %% [markdown]
# #### 1.1 We first look at the cumulative data

# %% [markdown]
# #### 1.1.1 Effect on T1ERI

# %%
fig, ax = plt.subplots(3,1,figsize=(12,12))

cm = plt.cm.get_cmap('Blues')

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    
    for maxqual in maxquals:
        for sigma in sigmas:
            T1ERI_list.append(H1000_Total[(tau,sigma,maxqual)]['T1'])
            #print('add data for ' + 'tau=' + tau + ' sig=' + sigma + 'msig=' + maxqual )
    x = np.array(sigmas)
    y = np.array(maxquals)
    z = np.array(T1ERI_list)
    X, Y = np.meshgrid(x,y)
    Z = z.reshape(len(maxquals),len(sigmas))
    
    # Generate 2D plot. All ticks are evenly spaced (despite their numerical values) since I'm plotting strings
    im = ax[i].pcolormesh(x, y.astype('str'), Z, cmap=cm, shading='nearest',edgecolors='k', linewidths=2)
    # Display the colorbar for each subplot
    cbar = fig.colorbar(im, ax=ax[i])
    cbar.ax.set_title('Total WC Time  (s)')
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$\sigma$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "$m_{\sigma}$",25)
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %% [markdown]
# #### 1.1.2 Effect on ERI Count

# %%
fig, ax = plt.subplots(3,1,figsize=(12,12))

cm = plt.cm.get_cmap('YlGn')

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        for sigma in sigmas:
            T1ERI_list.append(H1000_Total[(tau,sigma,maxqual)]['N1ERI'])
    x = np.array(sigmas)
    y = np.array(maxquals)
    z = np.array(T1ERI_list)
    X, Y = np.meshgrid(x,y)
    Z = z.reshape(len(maxquals),len(sigmas))
    
    # Generate 2D plot. All ticks are evenly spaced (despite their numerical values) since I'm plotting strings
    im = ax[i].pcolormesh(x, y.astype('str'), Z, cmap=cm, shading='nearest', vmin=Z.min(), vmax=Z.max(),edgecolors='k', linewidths=2)
    # Display the colorbar for each subplot
    cbar = fig.colorbar(im, ax=ax[i])
    cbar.ax.set_title('Total ERI count')
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$\sigma$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "$m_{\sigma}$",25)
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %% [markdown]
# #### 1.1.3 Effect on ERI Time

# %%
fig, ax = plt.subplots(3,1,figsize=(12,12))

cm = plt.cm.get_cmap('YlOrRd')

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        for sigma in sigmas:
            T1ERI_list.append(H1000_Total[(tau,sigma,maxqual)]['T1ERI_AllThreads'])
    x = np.array(sigmas)
    y = np.array(maxquals)
    z = np.array(T1ERI_list)
    X, Y = np.meshgrid(x,y)
    Z = z.reshape(len(maxquals),len(sigmas))
    
    # Generate 2D plot. All ticks are evenly spaced (despite their numerical values) since I'm plotting strings
    im = ax[i].pcolormesh(x, y.astype('str'), Z, cmap=cm, shading='nearest', vmin=Z.min(), vmax=Z.max(),edgecolors='k', linewidths=2)
    # Display the colorbar for each subplot
    cbar = fig.colorbar(im, ax=ax[i])
    cbar.ax.set_title('Total ERI Time AllThreads (s) ')
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$\sigma$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "$m_{\sigma}$",25)
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %%
fig, ax = plt.subplots(3,1,figsize=(12,12))

cm = plt.cm.get_cmap('YlOrRd')

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        for sigma in sigmas:
            T1ERI_list.append(H1000_Total[(tau,sigma,maxqual)]['T1ERI_WC'])
    x = np.array(sigmas)
    y = np.array(maxquals)
    z = np.array(T1ERI_list)
    X, Y = np.meshgrid(x,y)
    Z = z.reshape(len(maxquals),len(sigmas))
    
    # Generate 2D plot. All ticks are evenly spaced (despite their numerical values) since I'm plotting strings
    im = ax[i].pcolormesh(x, y.astype('str'), Z, cmap=cm, shading='nearest', vmin=Z.min(), vmax=Z.max(),edgecolors='k', linewidths=2)
    # Display the colorbar for each subplot
    cbar = fig.colorbar(im, ax=ax[i])
    cbar.ax.set_title('Total ERI Time WC (s) ')
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$\sigma$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "$m_{\sigma}$",25)
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %% [markdown]
# #### 1.1.4 Effect on Shrinking

# %%
fig, ax = plt.subplots(3,1,figsize=(12,12))

cm = plt.cm.get_cmap('Reds')

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        for sigma in sigmas:
            T1ERI_list.append(H1000_Total[(tau,sigma,maxqual)]['NShrink'])
    x = np.array(sigmas)
    y = np.array(maxquals)
    z = np.array(T1ERI_list)
    X, Y = np.meshgrid(x,y)
    Z = z.reshape(len(maxquals),len(sigmas))
    
    # Generate 2D plot. All ticks are evenly spaced (despite their numerical values) since I'm plotting strings
    im = ax[i].pcolormesh(x, y.astype('str'), Z, cmap=cm, shading='nearest', vmin=Z.min(), vmax=Z.max(),edgecolors='k', linewidths=2)
    # Display the colorbar for each subplot
    cbar = fig.colorbar(im, ax=ax[i])
    cbar.ax.set_title('Total Shrink Count')
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$\sigma$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "$m_{\sigma}$",25)
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %%
fig, ax = plt.subplots(3,1,figsize=(12,12))

cm = plt.cm.get_cmap('Reds')

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        for sigma in sigmas:
            T1ERI_list.append(H1000_Total[(tau,sigma,maxqual)]['TShrink'])
    x = np.array(sigmas)
    y = np.array(maxquals)
    z = np.array(T1ERI_list)
    X, Y = np.meshgrid(x,y)
    Z = z.reshape(len(maxquals),len(sigmas))
    
    # Generate 2D plot. All ticks are evenly spaced (despite their numerical values) since I'm plotting strings
    im = ax[i].pcolormesh(x, y.astype('str'), Z, cmap=cm, shading='nearest', vmin=Z.min(), vmax=Z.max(),edgecolors='k', linewidths=2)
    # Display the colorbar for each subplot
    cbar = fig.colorbar(im, ax=ax[i])
    cbar.ax.set_title('Total Shrink Time (s)')
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$\sigma$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "$m_{\sigma}$",25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %% [markdown]
# #### Now set $\sigma$ to 0 and investigate the effect of $m_{\sigma}$

# %%
# Construct the name of the output files 
root = '/Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/'
system = 'H1000'
basis = 'sto3g'
integral_engine = 'libint'
contraction_type = 's'
taus = ['1e-8', '1e-6', '1e-4'] 
sigma = 0
maxquals = np.arange(20,2020,20)

H1000_S0_Total = {}
H1000_S0_Progress = {}

for tau in taus:
    for maxqual in maxquals:

        fname = root + system

        fname += '_%s_%s%s' % (basis,integral_engine,contraction_type)

        fname += '_t%s_s%s_m%d' % (tau,sigma,maxqual)

        fname += '.out'

        print(fname)

        H1000_S0_Progress[(tau,sigma,maxqual)], H1000_S0_Total[(tau,sigma,maxqual)] = parseOutput(fname)
# Out:
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m20.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m40.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m60.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m80.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m100.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m120.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m140.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m160.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m180.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m200.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m220.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m240.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m260.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m280.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m300.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m320.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m340.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m360.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m380.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m400.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m420.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m440.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m460.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m480.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m500.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m520.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m540.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m560.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m580.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m600.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m620.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m640.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m660.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m680.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m700.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m720.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m740.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m760.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m780.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m800.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m820.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m840.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m860.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m880.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m900.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m920.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m940.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m960.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m980.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1000.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1020.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1040.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1060.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1080.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1100.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1120.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1140.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1160.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1180.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1200.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1220.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1240.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1260.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1280.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1300.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1320.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1340.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1360.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1380.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1400.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1420.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1440.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1460.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1480.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1500.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1520.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1540.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1560.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1580.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1600.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1620.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1640.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1660.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1680.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1700.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1720.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1740.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1760.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1780.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1800.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1820.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1840.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1860.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1880.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1900.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1920.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1940.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1960.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m1980.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-8_s0_m2000.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m20.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m40.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m60.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m80.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m100.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m120.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m140.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m160.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m180.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m200.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m220.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m240.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m260.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m280.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m300.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m320.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m340.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m360.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m380.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m400.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m420.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m440.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m460.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m480.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m500.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m520.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m540.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m560.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m580.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m600.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m620.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m640.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m660.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m680.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m700.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m720.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m740.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m760.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m780.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m800.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m820.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m840.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m860.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m880.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m900.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m920.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m940.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m960.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m980.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1000.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1020.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1040.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1060.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1080.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1100.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1120.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1140.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1160.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1180.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1200.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1220.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1240.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1260.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1280.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1300.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1320.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1340.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1360.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1380.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1400.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1420.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1440.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1460.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1480.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1500.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1520.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1540.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1560.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1580.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1600.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1620.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1640.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1660.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1680.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1700.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1720.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1740.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1760.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1780.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1800.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1820.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1840.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1860.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1880.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1900.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1920.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1940.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1960.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m1980.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-6_s0_m2000.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m20.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m40.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m60.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m80.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m100.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m120.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m140.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m160.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m180.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m200.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m220.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m240.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m260.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m280.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m300.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m320.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m340.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m360.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m380.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m400.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m420.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m440.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m460.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m480.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m500.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m520.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m540.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m560.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m580.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m600.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m620.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m640.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m660.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m680.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m700.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m720.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m740.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m760.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m780.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m800.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m820.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m840.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m860.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m880.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m900.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m920.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m940.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m960.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m980.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1000.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1020.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1040.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1060.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1080.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1100.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1120.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1140.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1160.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1180.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1200.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1220.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1240.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1260.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1280.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1300.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1320.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1340.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1360.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1380.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1400.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1420.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1440.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1460.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1480.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1500.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1520.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1540.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1560.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1580.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1600.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1620.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1640.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1660.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1680.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1700.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1720.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1740.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1760.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1780.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1800.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1820.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1840.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1860.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1880.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1900.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1920.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1940.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1960.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m1980.out
# /Users/aodongliu/LiGroup/cholesky/study_param/H1000/libint_seg/set_sigma_to_0/H1000_sto3g_libints_t1e-4_s0_m2000.out

# %%
sigma = 0

fig, ax = plt.subplots(3,1,figsize=(12,12))

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        T1ERI_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['T1'])
        
        
    ax[i].scatter(maxquals,T1ERI_list)
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$m_{\sigma}$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "T1 WC(s)",25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %%
sigma = 0

fig, ax = plt.subplots(3,1,figsize=(12,12))

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        T1ERI_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['N1ERI'])
        
        
    ax[i].scatter(maxquals,T1ERI_list)
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$m_{\sigma}$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "Total ERI Count",25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %%
sigma = 0

fig, ax = plt.subplots(3,1,figsize=(12,12))

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        T1ERI_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['T1ERI_AllThreads'])
        
        
    ax[i].scatter(maxquals,T1ERI_list)
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$m_{\sigma}$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "Total ERI Time All Threads(s)",25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %%
sigma = 0

fig, ax = plt.subplots(3,1,figsize=(12,12))

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        T1ERI_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['T1ERI_WC'])
        
        
    ax[i].scatter(maxquals,T1ERI_list)
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$m_{\sigma}$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "Total ERI Time WC(s)",25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %%
sigma = 0

fig, ax = plt.subplots(3,1,figsize=(12,12))

for i in range(3):
    tau = taus[i]
    T1ERI_list = []
    for maxqual in maxquals:
        T1ERI_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['NShrink'])
        
        
    ax[i].scatter(maxquals,T1ERI_list)
    ax[i].set_title(r"$ \tau=$" + tau)

plt.xlabel("$m_{\sigma}$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "Total Shrink Count",25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %%
sigma = 0

fig, ax = plt.subplots(3,1,figsize=(12,12))

for i in range(3):
    tau = taus[i]
    T1_list = []
    TShrink_list = []
    T1ERI_list = []
    for maxqual in maxquals:
        T1_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['T1'])
        TShrink_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['TShrink'])
        T1ERI_list.append(H1000_S0_Total[(tau,sigma,maxqual)]['T1ERI_WC'])
        
    ax[i].plot(maxquals,TShrink_list,'-b',label='Shrink Time')
    ax[i].plot(maxquals,T1ERI_list,'-r',label='ERI Time')
    ax[i].plot(maxquals,np.array(T1ERI_list) + np.array(TShrink_list),'-g',label='ERI+shrink')
    ax[i].plot(maxquals,np.array(T1_list) - np.array(T1ERI_list) - np.array(TShrink_list),'-o',label='gap')
    ax[i].plot(maxquals,T1_list,'-k',label='Total Time')
    ax[i].set_title(r"$ \tau=$" + tau)
    
    min_val, min_idx = min((val, idx) for (idx, val) in enumerate(T1_list))
    ax[i].axvline(maxquals[min_idx], linewidth=4, color='#1f77b4',label='Minimum')
    ax[i].text(maxquals[min_idx]+20, 0.5 * np.max( np.array(T1_list) ), 
           'at $m_{\sigma}=$'+str(maxquals[min_idx])+', $T_{min}=$'+str(min_val))
    ax[0].legend(loc='upper right')

plt.xlabel("$m_{\sigma}$",fontsize=25)
set_shared_ylabel((ax[0], ax[1], ax[2]), "Time)",25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
# <ipython-input-5-b5ddb0f08091>:23: MatplotlibDeprecationWarning:
# The inverse_transformed function was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use transformed(transform.inverted()) instead.
#   bboxes = bboxes.inverse_transformed(f.transFigure)

# %% [markdown]
# ### 1.2 Examine the trend during the cholesky decomposition

# %% [markdown]
# ###### To make the trends more clear, we choose sigma to be 0, and only use msigma to control the batch size

# %% [markdown]
# #### 1.2.1 Define functions to plot trend

# %%
def plot_ERI_size(data, tau, sigma, msigma):
    ERI_progress = data[tau,sigma,msigma]['ERI_vec']
    x = np.arange(1,len(ERI_progress)+1,1)
    plt.plot(x,ERI_progress)
    plt.show()

# %%
plot_ERI_size(H1000_Progress,'1e-8','1',1)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plot_ERI_size(H1000_Progress,'1e-8','1e-2',1000)
# Out:
# <img src="data:image/png;base64,..." width="432">
